# %%
import os
os.chdir('/mnt/c/Users/ralvin/OneDrive - Reliant Health Partners/Documents/RHP_dev_RA/Automate_skyvia')
import pandas as pd
from simple_salesforce import Salesforce, SalesforceLogin
import pyodbc, sys, time 
import requests
import numpy as np
from datetime import datetime
from helper_functions_v2 import create_df, updated_data_pull, upsert, delete_record, insert_records, salesforce_connection, read_sftp_data
import configparser
import json
import paramiko
import io

pd.set_option('display.max_rows', None) 
pd.set_option('display.max_columns', None) 


##### retrieve source data
config = configparser.ConfigParser()
config.read('config.ini')
sftp_config = config['sftp']
mapping_config = config['mappings']
host = sftp_config.get('host')
port = sftp_config.getint('port', fallback=22) 
username = sftp_config.get('user')
password = sftp_config.get('password')
remote_path = sftp_config.get('remote_path')
json_path = mapping_config.get('json_file_path')


Source_data =  read_sftp_data(remote_path, host, port, username, password)
print(f'Source data shape: {Source_data.shape}')


## get data mappings 
with open(json_path, 'r') as f:
    data = json.load(f)

mappings = {k:v for k,v in data.items()}
Claims_map = mappings['Claim_Object_Map']
Account_map = mappings['Account_Object_Map']
Povider_map = mappings['Provider_Object_Map']
lines_map = mappings['Line_Item_Object_Map']

## sf connection
sf = salesforce_connection(sandbox=True)
sf_prod = salesforce_connection(sandbox=False)




## data pull
# sf_objects = ["Claims__c", "Line_Items__c", "Provider_TIN__c", 'Jurisdiction__c', 'Groups_Clients__c', 'DRG__c', 
#                  'HCPCS_CPT_Code__c', 'Account', 'Clients__c', 'Provider_Specialty__c']
# my_sf_objects = updated_data_pull(sf_objects, sf)
# for key in my_sf_objects:
#     print(key)
#     print(my_sf_objects[key].shape)


#### logging is done on a file level... ideally we archive file into review dir and have info on all errors with respect to file
# Out:
# Connection established successfully!
# File read into DataFrame successfully
# Connection closed.
# Source data shape: (446, 42)
# Connected to Salesforce sandbox
# Connected to Salesforce Prod

# %%
claims_sf = updated_data_pull(['Claims__c'], sf)
Line_items_sf = updated_data_pull(['Line_Items__c'], sf)
print(claims_sf.shape)
print(Line_items_sf.shape)
# Out:
# pulled Claims__c
# pulled Line_Items__c
# (12937, 101)
# (22841, 49)

# %%
def data_pull(object_name, id_list, sf):
    
    sf_object = getattr(sf, object_name)

    # Retrieve and print field names
    metadata = sf_object.describe()
    field_names = [field['name'] for field in metadata['fields']]

    # Construct the SOQL query with ID filtering
    id_filter = "', '".join(id_list)
    query = f"SELECT {', '.join(field_names)} FROM {object_name} WHERE Id IN ('{id_filter}')"
    
    # Retrieve records
    records = sf.query(query)
    all_records = records['records']
    

    # Handle pagination
    while not records['done']:
        records = sf.query_more(records['nextRecordsUrl'], True)
        all_records.extend(records['records'])

    # Convert to DataFrame
    df = pd.DataFrame(all_records)

    # Check if DataFrame is empty
    if df.shape == (0, 0):
        raise ValueError("DataFrame is empty (shape is (0, 0)). No data retrieved.")

    # Remove Salesforce metadata keys if present
    df = df.drop(columns=['attributes'], errors='ignore')

    print('pulled data slice!')

    return df



def create_df(source_dict, Source_data, sf, id_list = None):

    new_columns = [col for mapped_cols in source_dict['MAPPINGS'].values() for col in mapped_cols]
    new_df = pd.DataFrame(columns=new_columns)
    keys = source_dict['KEYS']

    try:
        Table_convert_cols = list(source_dict['TABLE_CONVERT'].keys())
    except:
        Table_convert_cols = []

    for source_col, target_cols in source_dict['MAPPINGS'].items():
        if source_col in Table_convert_cols:
            map_table = source_dict['TABLE_CONVERT'][source_col]
            try:
                string_ids = [
                        str(int(float(id))) if pd.notna(id) and id != 'nan' else np.nan
                        for id in Source_data[source_col]                               #### handeling DRG col
                    ]
            except:
                string_ids = [str(id) for id in Source_data[source_col]]
                
            Source_data[source_col] = string_ids #### col update to match same type in foreign table
            foreign_table = list(map_table.keys())[0]
            print(f'pulling updated {foreign_table} table')
        
            try:
                sf_object = data_pull(foreign_table, id_list, sf)  #### passing in idlist to prevent pulling entire object
            except Exception as e:
                sf_object = None  # Ensure sf_object is set to None if there's an exception


            if sf_object is None:
                sf_object = updated_data_pull([foreign_table], sf) #### need logic to pull only the records I need rather than the entire table
                


            merged = Source_data.merge(sf_object.loc[:, map_table[foreign_table]], left_on=source_col, right_on=map_table[foreign_table][0], how='left')
       
            print(f'Merged {source_col}')
            for i, target_col in enumerate(target_cols):

                foreign_col = map_table[foreign_table][i+1]
                new_df[target_col] = merged[foreign_col]
              


        if source_col not in Table_convert_cols:
            if source_col in Source_data.columns:
                for target_col in target_cols:
                    new_df[target_col] = Source_data[source_col]
        



    return new_df, keys

# %%
# map_account_table, _ = create_df(Account_map, Source_data, sf)
# map_provider_table, keys = create_df(Povider_map, Source_data, sf)
# ###upsert account and provider records
# new_ids, errors = upsert(map_provider_table.drop_duplicates(), keys, sf)

# %%
##### populate claims obj on sf

map_claims_table, keys = create_df(Claims_map, Source_data, sf)
new_ids, errors = insert_records(map_claims_table.drop_duplicates(), keys, sf) ###insert new claims records
# Out:
# pulling updated Provider_TIN__c table
# pulled Provider_TIN__c
# Merged TIN
# pulling updated Groups_Clients__c table
# pulled Groups_Clients__c
# Merged Patient Group/Policy Number
# pulling updated Jurisdiction__c table
# pulled Jurisdiction__c
# Merged JurisdictionState
# pulling updated DRG__c table
# pulled DRG__c
# Merged DRG
# pulling updated Provider_Specialty__c table
# pulled Provider_Specialty__c
# Merged Billing Provider Taxonomy
# Processing record 0: {'Claim_ID__c': 'A3038B5E4B6C914tksft', 'Provider_TIN__c': 'a0FVF000001zh5t2AA', 'Group_Client__c': 'a0C8a00000r3GJ6EAM', 'Claim_Number__c': '431817310700011', 'Jurisdiction__c': 'a024W00000ICbumQAD', 'Diag_Code__c': 'M25562', 'Diag_Code_2nd__c': nan, 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'KAISER FOUNDATION HOSPITALS ', 'Patient__c': 'WATKINS MONIC  ', 'Patient_ID__c': '569713835', 'Date_of_Birth__c': '08/12/1982', 'Provider_Zip__c': 900749998, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': nan, 'POS__c': 13, 'Provider_Specialty__c': 'a008a000015yXODAA2', 'Service_Type__c': 'OUTPATIENT'}
# Processing record 1: {'Claim_ID__c': 'BE9124A610A9998tksft', 'Provider_TIN__c': 'a0F4W00000W1KI4UAN', 'Group_Client__c': 'a0C8a00000sg4tZEAQ', 'Claim_Number__c': 'CLU20241115325204', 'Jurisdiction__c': 'a024W00000HYAjJQAX', 'Diag_Code__c': 'M7672', 'Diag_Code_2nd__c': 'M722', 'Diag_Code_3rd__c': 'M7732', 'Diag_Code_4th__c': nan, 'Provider__c': 'JOHNSON MEMORIAL HOSPITAL ', 'Patient__c': 'FISHER TERRI ', 'Patient_ID__c': 'QWCR14517', 'Date_of_Birth__c': '01/11/1974', 'Provider_Zip__c': 461312140, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': 1578930186.0, 'POS__c': 13, 'Provider_Specialty__c': 'a008a000015yXODAA2', 'Service_Type__c': 'OUTPATIENT'}
# Processing record 2: {'Claim_ID__c': '317D671330C4442tksft', 'Provider_TIN__c': 'a0FVF000001f3W22AI', 'Group_Client__c': 'a0CUu000001thoWMAQ', 'Claim_Number__c': 'U424319281216', 'Jurisdiction__c': 'a024W00000HYAjcQAH', 'Diag_Code__c': 'Z1211', 'Diag_Code_2nd__c': 'K635', 'Diag_Code_3rd__c': 'K648', 'Diag_Code_4th__c': 'K2950', 'Provider__c': 'DEACONESS HENDERSON HOSPII ', 'Patient__c': 'COBB BETHAN  ', 'Patient_ID__c': 'FBDS11454', 'Date_of_Birth__c': '03/12/1984', 'Provider_Zip__c': 452638704, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': 1295211563.0, 'POS__c': 13, 'Provider_Specialty__c': 'a008a000015yXODAA2', 'Service_Type__c': 'OUTPATIENT'}
# Processing record 3: {'Claim_ID__c': 'B7D4248A586D86Ftksft', 'Provider_TIN__c': 'a0FVF0000020Oyr2AE', 'Group_Client__c': 'a0C8a000017cPdoEAE', 'Claim_Number__c': 'E24317I1000001', 'Jurisdiction__c': 'a024W00000ICbumQAD', 'Diag_Code__c': 'M4802', 'Diag_Code_2nd__c': 'M5412', 'Diag_Code_3rd__c': 'M2578', 'Diag_Code_4th__c': 'G992', 'Provider__c': 'MARIN SPECIALTY SURGERY CENTER ', 'Patient__c': 'REUSSWIG ANNE-LISE ', 'Patient_ID__c': '142729742', 'Date_of_Birth__c': '02/26/1971', 'Provider_Zip__c': 949030070, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': nan, 'POS__c': 24, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 4: {'Claim_ID__c': '61A21FFFC4CC0F3tksft', 'Provider_TIN__c': 'a0FVF0000020P0T2AU', 'Group_Client__c': 'a0C8a00000r3Gf3EAE', 'Claim_Number__c': '243183637H', 'Jurisdiction__c': 'a024W00000HYAjkQAH', 'Diag_Code__c': 'I5020', 'Diag_Code_2nd__c': 'I4891', 'Diag_Code_3rd__c': 'I2720', 'Diag_Code_4th__c': 'I361', 'Provider__c': 'BAPTIST HOSPITAL ', 'Patient__c': 'JEWELL RONALD  A', 'Patient_ID__c': 'MB00261557', 'Date_of_Birth__c': '09/29/1952', 'Provider_Zip__c': 753736685, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': 1225038557.0, 'POS__c': 13, 'Provider_Specialty__c': 'a008a000015yXODAA2', 'Service_Type__c': 'OUTPATIENT'}
# Processing record 5: {'Claim_ID__c': 'D8E091C0F41F56Btksft', 'Provider_TIN__c': 'a0FVF000001zh5t2AA', 'Group_Client__c': 'a0C8a00000r3GJ6EAM', 'Claim_Number__c': '431817310700001', 'Jurisdiction__c': 'a024W00000ICbumQAD', 'Diag_Code__c': 'S0990XA', 'Diag_Code_2nd__c': 'W1839XA', 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'KAISER FOUNDATION HOSPITALS ', 'Patient__c': 'Goodrich Lorena  ', 'Patient_ID__c': '626694799', 'Date_of_Birth__c': '06/29/1996', 'Provider_Zip__c': 900749998, 'DRG__c': nan, 'QPA__c': 'Y', 'NPI__c': nan, 'POS__c': 13, 'Provider_Specialty__c': 'a008a000015yXODAA2', 'Service_Type__c': 'OUTPATIENT'}
# Processing record 6: {'Claim_ID__c': '67088D981A619DFtksft', 'Provider_TIN__c': 'a0F4W00000W1LmPUAV', 'Group_Client__c': 'a0C8a00000r3G8IEAU', 'Claim_Number__c': '431705422700011', 'Jurisdiction__c': 'a024W00000HYAjlQAH', 'Diag_Code__c': 'S46012A', 'Diag_Code_2nd__c': nan, 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'DELTA COMMUNITY HOSPITAL PHYSI ', 'Patient__c': 'BRONSON SHELDON ', 'Patient_ID__c': '870388573', 'Date_of_Birth__c': '03/19/1962', 'Provider_Zip__c': 841309998, 'DRG__c': nan, 'QPA__c': 'Y', 'NPI__c': 1962504068.0, 'POS__c': 13, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 7: {'Claim_ID__c': 'EAD0F19B861A871tksft', 'Provider_TIN__c': 'a0FVF0000020P252AE', 'Group_Client__c': 'a0C8a000017cLSwEAM', 'Claim_Number__c': '243192846Q', 'Jurisdiction__c': 'a024W00000HYAjcQAH', 'Diag_Code__c': 'R350', 'Diag_Code_2nd__c': 'K5901', 'Diag_Code_3rd__c': 'R399', 'Diag_Code_4th__c': 'R3915', 'Provider__c': 'CHILDRENS HOSPITAL MEDICAL CENTER O ', 'Patient__c': 'HUSK GIDEON ', 'Patient_ID__c': 'MB00491566', 'Date_of_Birth__c': '08/01/2018', 'Provider_Zip__c': 443081062, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': 1346403227.0, 'POS__c': 13, 'Provider_Specialty__c': 'a008a000015yXOEAA2', 'Service_Type__c': 'OUTPATIENT'}
# Processing record 8: {'Claim_ID__c': '01C3FF89C522BD5tksft', 'Provider_TIN__c': 'a0FVF000000uPgT2AU', 'Group_Client__c': 'a0CUu000002byniMAA', 'Claim_Number__c': '725003587730', 'Jurisdiction__c': 'a024W00000HYAjDQAX', 'Diag_Code__c': 'S91002A', 'Diag_Code_2nd__c': nan, 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'HOME CARE CONNECT ', 'Patient__c': 'Castillo-Matos Sofia ', 'Patient_ID__c': '999999999', 'Date_of_Birth__c': '01/08/1973', 'Provider_Zip__c': 327169998, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': nan, 'POS__c': 32, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 9: {'Claim_ID__c': '63CE584016F6D3Ftksft', 'Provider_TIN__c': 'a0FVF0000020P3h2AE', 'Group_Client__c': 'a0C8a00000r3NZyEAM', 'Claim_Number__c': 'Z24320I1000044', 'Jurisdiction__c': 'a024W00000HYAjfQAH', 'Diag_Code__c': 'F250', 'Diag_Code_2nd__c': 'F411', 'Diag_Code_3rd__c': 'G4700', 'Diag_Code_4th__c': nan, 'Provider__c': 'CHRIST HOSPITAL ', 'Patient__c': 'GIOVINE PADILLA TERESA ', 'Patient_ID__c': '142606484', 'Date_of_Birth__c': '03/05/1967', 'Provider_Zip__c': 191824678, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': nan, 'POS__c': 22, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 10: {'Claim_ID__c': '6EE25F5AB46D44Etksft', 'Provider_TIN__c': 'a0FVF0000020P5J2AU', 'Group_Client__c': 'a0CUu00000BrjTqMAJ', 'Claim_Number__c': '243182401Q', 'Jurisdiction__c': 'a024W00000HYAjIQAX', 'Diag_Code__c': 'Z1211', 'Diag_Code_2nd__c': 'K5100', 'Diag_Code_3rd__c': 'K621', 'Diag_Code_4th__c': 'K620', 'Provider__c': 'BELTWAY SURGERY CENTER LLC ', 'Patient__c': 'WHITE DEBRA ', 'Patient_ID__c': '314729378', 'Date_of_Birth__c': '08/25/1958', 'Provider_Zip__c': 606860000, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': 1164486643.0, 'POS__c': 83, 'Provider_Specialty__c': 'a008a000015yXNEAA2', 'Service_Type__c': 'SURGERY CENTER'}
# Processing record 11: {'Claim_ID__c': 'C9F64E24925EDB0tksft', 'Provider_TIN__c': 'a0FVF0000020P6v2AE', 'Group_Client__c': 'a0C8a00000r3NaaEAE', 'Claim_Number__c': 'A24317I1000008', 'Jurisdiction__c': 'a024W00000HYAjOQAX', 'Diag_Code__c': 'Z48815', 'Diag_Code_2nd__c': 'K5720', 'Diag_Code_3rd__c': 'Z9049', 'Diag_Code_4th__c': 'R21', 'Provider__c': 'EASTERN MAINE MEDICAL CENTER ', 'Patient__c': 'OSMAN TIMOTHY  ', 'Patient_ID__c': '172644585', 'Date_of_Birth__c': '01/06/1968', 'Provider_Zip__c': 44121006, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': nan, 'POS__c': 22, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 12: {'Claim_ID__c': '2A63E66B14A560Dtksft', 'Provider_TIN__c': 'a0F4W00000W1LmPUAV', 'Group_Client__c': 'a0C8a00000r3G8IEAU', 'Claim_Number__c': '431705422700001', 'Jurisdiction__c': 'a024W00000HYAjlQAH', 'Diag_Code__c': 'S52571A', 'Diag_Code_2nd__c': 'Z85820', 'Diag_Code_3rd__c': 'K219', 'Diag_Code_4th__c': 'Z79899', 'Provider__c': 'INTERMOUNTAIN MEDICAL CENTER ', 'Patient__c': 'LOFGRAN TIFFANY ', 'Patient_ID__c': '876000494', 'Date_of_Birth__c': '12/19/1966', 'Provider_Zip__c': 841309998, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': 1043220650.0, 'POS__c': 13, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 13: {'Claim_ID__c': '7A540C88FD80A89tksft', 'Provider_TIN__c': 'a0FVF0000020P8X2AU', 'Group_Client__c': 'a0C8a00000r3NZyEAM', 'Claim_Number__c': 'Z24320I1000070', 'Jurisdiction__c': 'a024W00000HYAjDQAX', 'Diag_Code__c': 'F332', 'Diag_Code_2nd__c': 'F4310', 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'DEERFIELD FLORIDA HOUSE INC ', 'Patient__c': 'BATES DAMIEN  ', 'Patient_ID__c': '156861764', 'Date_of_Birth__c': '07/26/1989', 'Provider_Zip__c': 334414117, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': nan, 'POS__c': 22, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 14: {'Claim_ID__c': 'C289FE1803B0D66tksft', 'Provider_TIN__c': 'a0FVF0000020P3h2AE', 'Group_Client__c': 'a0C8a00000r3NZxEAM', 'Claim_Number__c': 'Z24318I1000046', 'Jurisdiction__c': 'a024W00000HYAjfQAH', 'Diag_Code__c': 'F3181', 'Diag_Code_2nd__c': nan, 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'CHRIST HOSPITAL ', 'Patient__c': 'ROMAN MAGALY ', 'Patient_ID__c': '142524266', 'Date_of_Birth__c': '06/25/1969', 'Provider_Zip__c': 191824678, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': nan, 'POS__c': 22, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 15: {'Claim_ID__c': 'FC86832D0A048DBtksft', 'Provider_TIN__c': 'a0FVF0000020PA92AM', 'Group_Client__c': 'a0C8a00000r3NaUEAU', 'Claim_Number__c': 'Z24320I1000023', 'Jurisdiction__c': 'a024W00000HYAjYQAX', 'Diag_Code__c': 'F411', 'Diag_Code_2nd__c': 'F3341', 'Diag_Code_3rd__c': 'F902', 'Diag_Code_4th__c': nan, 'Provider__c': 'INTEGRATED CARE CONSULTING L ', 'Patient__c': 'OCONNOR DILELLO KATHLEEN ', 'Patient_ID__c': '148769413', 'Date_of_Birth__c': '04/08/2008', 'Provider_Zip__c': 77241234, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': nan, 'POS__c': 22, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 16: {'Claim_ID__c': 'B86FE317E90FBF9tksft', 'Provider_TIN__c': 'a0F4W00000W1JHZUA3', 'Group_Client__c': 'a0C8a00000r3Gf3EAE', 'Claim_Number__c': '243192203Q', 'Jurisdiction__c': 'a024W00000HYAjjQAH', 'Diag_Code__c': 'R293', 'Diag_Code_2nd__c': 'M7501', 'Diag_Code_3rd__c': 'M6281', 'Diag_Code_4th__c': 'M25512', 'Provider__c': 'BAPTIST MEMORIAL HOSPITAL ', 'Patient__c': 'COX JAMES  A', 'Patient_ID__c': 'MB04888449', 'Date_of_Birth__c': '07/24/1969', 'Provider_Zip__c': 380170601, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': 1497198865.0, 'POS__c': 13, 'Provider_Specialty__c': 'a008a000015yXODAA2', 'Service_Type__c': 'OUTPATIENT'}
# Processing record 17: {'Claim_ID__c': 'ECB3A5AE9C1A1C0tksft', 'Provider_TIN__c': 'a0FVF0000020PBl2AM', 'Group_Client__c': 'a0C8a00000r3NZxEAM', 'Claim_Number__c': 'Z24318I1000095', 'Jurisdiction__c': 'a024W00000ICbumQAD', 'Diag_Code__c': 'F1320', 'Diag_Code_2nd__c': 'F13239', 'Diag_Code_3rd__c': 'F1420', 'Diag_Code_4th__c': 'F1423', 'Provider__c': 'LEGACY HEALING CENTER CALIFORNIA ', 'Patient__c': 'RUBINO MARGARET  ', 'Patient_ID__c': '155583644', 'Date_of_Birth__c': '12/15/1962', 'Provider_Zip__c': 900461741, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': nan, 'POS__c': 21, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 18: {'Claim_ID__c': 'E95C2D3177BDC10tksft', 'Provider_TIN__c': 'a0FVF0000020PDN2A2', 'Group_Client__c': 'a0C4W00000dJpXeUAK', 'Claim_Number__c': 'ECM2024111318213', 'Jurisdiction__c': 'a024W00000HYAjLQAX', 'Diag_Code__c': 'N921', 'Diag_Code_2nd__c': nan, 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'OCHSNER AMERICAN LEGION HOSPITAL ', 'Patient__c': 'THAMES HANNAH ', 'Patient_ID__c': 'E11136105-01', 'Date_of_Birth__c': '07/31/2005', 'Provider_Zip__c': 705469998, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': nan, 'POS__c': 13, 'Provider_Specialty__c': 'a008a000015yXODAA2', 'Service_Type__c': 'OUTPATIENT'}
# Processing record 19: {'Claim_ID__c': 'B8454DD2D356F9Etksft', 'Provider_TIN__c': 'a0F8a00001Rft3ZEAR', 'Group_Client__c': 'a0C8a000017cOdWEAU', 'Claim_Number__c': '243190934Q', 'Jurisdiction__c': 'a024W00000HYAjJQAX', 'Diag_Code__c': 'Z1231', 'Diag_Code_2nd__c': nan, 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'IU HEALTH TIPTON HOSPITAL ', 'Patient__c': 'HAMILTON KELLY  ', 'Patient_ID__c': '311823810', 'Date_of_Birth__c': '01/15/1965', 'Provider_Zip__c': 460729753, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': 1063505667.0, 'POS__c': 85, 'Provider_Specialty__c': 'a008a000015yXOFAA2', 'Service_Type__c': 'OUTPATIENT'}
# Processing record 20: {'Claim_ID__c': 'CD421166FF03991tksft', 'Provider_TIN__c': 'a0FVF0000020P3h2AE', 'Group_Client__c': 'a0C8a00000r3NZyEAM', 'Claim_Number__c': 'Z24318I1000001', 'Jurisdiction__c': 'a024W00000HYAjfQAH', 'Diag_Code__c': 'F250', 'Diag_Code_2nd__c': 'F411', 'Diag_Code_3rd__c': 'G4700', 'Diag_Code_4th__c': nan, 'Provider__c': 'CHRIST HOSPITAL ', 'Patient__c': 'GIOVINE PADILLA TERESA ', 'Patient_ID__c': '142606484', 'Date_of_Birth__c': '03/05/1967', 'Provider_Zip__c': 191824678, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': nan, 'POS__c': 22, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 21: {'Claim_ID__c': 'B33F7CB3C7C8DF5tksft', 'Provider_TIN__c': 'a0F4W00000W1IF6UAN', 'Group_Client__c': 'a0C8a000017cPdoEAE', 'Claim_Number__c': 'E24318I1000013', 'Jurisdiction__c': 'a024W00000HYAjYQAX', 'Diag_Code__c': 'I214', 'Diag_Code_2nd__c': 'I161', 'Diag_Code_3rd__c': 'E119', 'Diag_Code_4th__c': 'N179', 'Provider__c': 'OLD BRIDGE MEDICAL CENTER ', 'Patient__c': 'NAIK PRASANNA  ', 'Patient_ID__c': '099765543', 'Date_of_Birth__c': '05/21/1967', 'Provider_Zip__c': 88573012, 'DRG__c': 'a014W00000ym3XXQAY', 'QPA__c': 'Y', 'NPI__c': nan, 'POS__c': 21, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 22: {'Claim_ID__c': '26943674CF2485Etksft', 'Provider_TIN__c': 'a0F4W00000W1KR6UAN', 'Group_Client__c': 'a0C8a00000r3Gf3EAE', 'Claim_Number__c': '243190940Q', 'Jurisdiction__c': 'a024W00000HYAjjQAH', 'Diag_Code__c': 'H00012', 'Diag_Code_2nd__c': 'F17210', 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'ST FRANCIS BARTLETT ', 'Patient__c': 'HABEEB OMAR  ', 'Patient_ID__c': 'MB03781455', 'Date_of_Birth__c': '10/09/2000', 'Provider_Zip__c': 381334003, 'DRG__c': nan, 'QPA__c': 'Y', 'NPI__c': 1114055845.0, 'POS__c': 13, 'Provider_Specialty__c': 'a008a000015yXODAA2', 'Service_Type__c': 'OUTPATIENT'}
# Processing record 23: {'Claim_ID__c': '57C0167FE471D8Ftksft', 'Provider_TIN__c': 'a0FVF0000020PEz2AM', 'Group_Client__c': 'a0C8a00000r3NaUEAU', 'Claim_Number__c': 'Z24320I1000024', 'Jurisdiction__c': 'a024W00000ICburQAD', 'Diag_Code__c': 'F332', 'Diag_Code_2nd__c': nan, 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'CT CLINICAL SERVICES INC ', 'Patient__c': 'OCONNOR DILELLO KATHLEEN ', 'Patient_ID__c': '148769413', 'Date_of_Birth__c': '04/08/2008', 'Provider_Zip__c': 65102014, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': nan, 'POS__c': 55, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 24: {'Claim_ID__c': '5055E78B92F0498tksft', 'Provider_TIN__c': 'a0F4W00000W1JHZUA3', 'Group_Client__c': 'a0C8a00000r3Gf3EAE', 'Claim_Number__c': '243192332Q', 'Jurisdiction__c': 'a024W00000HYAjjQAH', 'Diag_Code__c': 'R1011', 'Diag_Code_2nd__c': nan, 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'BAPTIST MEMORIAL HOSPITAL ', 'Patient__c': 'WHITTEN MAUREEN  ', 'Patient_ID__c': 'MB03521926', 'Date_of_Birth__c': '12/29/1964', 'Provider_Zip__c': 381202113, 'DRG__c': nan, 'QPA__c': 'Y', 'NPI__c': 1629575071.0, 'POS__c': 13, 'Provider_Specialty__c': 'a008a000015yXODAA2', 'Service_Type__c': 'OUTPATIENT'}
# Processing record 25: {'Claim_ID__c': '1E6E757A964D548tksft', 'Provider_TIN__c': 'a0F4W00000W1KH5UAN', 'Group_Client__c': nan, 'Claim_Number__c': '18A91B0008179A1', 'Jurisdiction__c': 'a024W00000HYAjJQAX', 'Diag_Code__c': 'C20', 'Diag_Code_2nd__c': 'C7951', 'Diag_Code_3rd__c': 'R6889', 'Diag_Code_4th__c': nan, 'Provider__c': 'METHODIST HOSPITALSINC. ', 'Patient__c': 'ROODZANT JAMES  ', 'Patient_ID__c': '880263595', 'Date_of_Birth__c': '12/22/1971', 'Provider_Zip__c': 464107035, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': 1518035369.0, 'POS__c': 13, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Error during insert: Malformed request https://relianthealthpartners2020--tctdev.sandbox.my.salesforce.com/services/data/v59.0/sobjects/Claims__c/. Response content: [{'message': 'Required fields are missing: [Group_Client__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['Group_Client__c']}]
# Processing record 26: {'Claim_ID__c': '19609E48522EDE6tksft', 'Provider_TIN__c': 'a0F4W00000W1K3RUAV', 'Group_Client__c': 'a0C8a00000r3KpvEAE', 'Claim_Number__c': '243192198Q', 'Jurisdiction__c': 'a024W00000HYAjcQAH', 'Diag_Code__c': 'F909', 'Diag_Code_2nd__c': 'R41840', 'Diag_Code_3rd__c': 'R480', 'Diag_Code_4th__c': 'F800', 'Provider__c': 'CHILDRENS HOS MED CTR CH ', 'Patient__c': 'NEWMAN JETER ', 'Patient_ID__c': '644078468', 'Date_of_Birth__c': '07/07/2017', 'Provider_Zip__c': 452293039, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': 1114328267.0, 'POS__c': 13, 'Provider_Specialty__c': 'a008a000015yXOEAA2', 'Service_Type__c': 'OUTPATIENT'}
# Processing record 27: {'Claim_ID__c': '74E8CC6D7D7774Etksft', 'Provider_TIN__c': 'a0FVF0000020PGb2AM', 'Group_Client__c': 'a0C8a00000r3NaOEAU', 'Claim_Number__c': 'A24318I1000003', 'Jurisdiction__c': 'a024W00000HYAjYQAX', 'Diag_Code__c': 'F411', 'Diag_Code_2nd__c': nan, 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'CCC COUNSELING INC ', 'Patient__c': 'HARDING ABIGAIL ', 'Patient_ID__c': '144867806', 'Date_of_Birth__c': '05/27/2010', 'Provider_Zip__c': 87012256, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': nan, 'POS__c': 22, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 28: {'Claim_ID__c': '17C920EEFA3346Atksft', 'Provider_TIN__c': 'a0FVF000001zh5t2AA', 'Group_Client__c': 'a0C8a00000r3GJ6EAM', 'Claim_Number__c': '431817310700021', 'Jurisdiction__c': 'a024W00000ICbumQAD', 'Diag_Code__c': 'S82002A', 'Diag_Code_2nd__c': 'W11XXXA', 'Diag_Code_3rd__c': 'M109', 'Diag_Code_4th__c': 'G4733', 'Provider__c': 'KAISER FOUNDATION HOSPITALS ', 'Patient__c': 'Roxas Geofrey  ', 'Patient_ID__c': '612496855', 'Date_of_Birth__c': '01/24/1971', 'Provider_Zip__c': 900749998, 'DRG__c': nan, 'QPA__c': 'Y', 'NPI__c': nan, 'POS__c': 13, 'Provider_Specialty__c': 'a008a000015yXODAA2', 'Service_Type__c': 'OUTPATIENT'}
# Processing record 29: {'Claim_ID__c': 'FB0F2EA133AE755tksft', 'Provider_TIN__c': 'a0F4W00000W1KI2UAN', 'Group_Client__c': 'a0CUu00000BrjTqMAJ', 'Claim_Number__c': '243192212Q', 'Jurisdiction__c': 'a024W00000HYAjJQAX', 'Diag_Code__c': 'K8050', 'Diag_Code_2nd__c': 'R109', 'Diag_Code_3rd__c': 'R7401', 'Diag_Code_4th__c': 'R748', 'Provider__c': 'SULLIVAN COUNTY COMM HOSPITAL ', 'Patient__c': 'KREISCHER JAIME ', 'Patient_ID__c': '307881944', 'Date_of_Birth__c': '06/19/1976', 'Provider_Zip__c': 478827523, 'DRG__c': nan, 'QPA__c': 'Y', 'NPI__c': 1891312674.0, 'POS__c': 13, 'Provider_Specialty__c': 'a008a000015yXOFAA2', 'Service_Type__c': 'OUTPATIENT'}
# Processing record 30: {'Claim_ID__c': '2B42591B17C78C8tksft', 'Provider_TIN__c': 'a0FVF0000020PID2A2', 'Group_Client__c': 'a0C8a00000r3Gf3EAE', 'Claim_Number__c': '243183503H', 'Jurisdiction__c': 'a024W00000ICbumQAD', 'Diag_Code__c': 'S01112A', 'Diag_Code_2nd__c': 'F10120', 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'SMH LA JOLLA IMAGING PAVILION ', 'Patient__c': 'GREENE ZIMMER ', 'Patient_ID__c': 'MB02428816', 'Date_of_Birth__c': '09/13/2002', 'Provider_Zip__c': 900740333, 'DRG__c': nan, 'QPA__c': 'Y', 'NPI__c': 1114196862.0, 'POS__c': 13, 'Provider_Specialty__c': 'a008a000015yXFAAA2', 'Service_Type__c': 'PHYSICIAN'}
# Processing record 31: {'Claim_ID__c': 'B7CC5FD1E4AB8C7tksft', 'Provider_TIN__c': 'a0F4W00000W1KR6UAN', 'Group_Client__c': 'a0C8a00000r3Gf3EAE', 'Claim_Number__c': '243190942Q', 'Jurisdiction__c': 'a024W00000HYAjjQAH', 'Diag_Code__c': 'R102', 'Diag_Code_2nd__c': 'R1030', 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'ST FRANCIS BARTLETT ', 'Patient__c': 'MOBLEY KELSEY  ', 'Patient_ID__c': 'MB01300945', 'Date_of_Birth__c': '05/17/1991', 'Provider_Zip__c': 381334003, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': 1215426036.0, 'POS__c': 13, 'Provider_Specialty__c': 'a008a000015yXODAA2', 'Service_Type__c': 'OUTPATIENT'}
# Processing record 32: {'Claim_ID__c': 'FC1A91C1BE3DFD2tksft', 'Provider_TIN__c': 'a0F4W00000W1KR6UAN', 'Group_Client__c': 'a0C8a00000r3Gf3EAE', 'Claim_Number__c': '243190939Q', 'Jurisdiction__c': 'a024W00000HYAjjQAH', 'Diag_Code__c': 'R109', 'Diag_Code_2nd__c': nan, 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'ST FRANCIS BARTLETT ', 'Patient__c': 'BRADSHAW KATRINA  D', 'Patient_ID__c': 'MB02091047', 'Date_of_Birth__c': '03/24/1973', 'Provider_Zip__c': 381334003, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': 1093752198.0, 'POS__c': 13, 'Provider_Specialty__c': 'a008a000015yXODAA2', 'Service_Type__c': 'OUTPATIENT'}
# Processing record 33: {'Claim_ID__c': 'D0239CF7E90405Ctksft', 'Provider_TIN__c': 'a0F4W00000W1LftUAF', 'Group_Client__c': 'a0C8a00000r3G8IEAU', 'Claim_Number__c': '431907451200017', 'Jurisdiction__c': 'a024W00000ICbumQAD', 'Diag_Code__c': 'Z7721', 'Diag_Code_2nd__c': 'F17210', 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'DEACONESS HOSPITAL ', 'Patient__c': 'MOORE CHERAYA ', 'Patient_ID__c': '911151502', 'Date_of_Birth__c': '09/09/2001', 'Provider_Zip__c': 911899998, 'DRG__c': nan, 'QPA__c': 'Y', 'NPI__c': 1356528269.0, 'POS__c': 13, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 34: {'Claim_ID__c': '66023587B3A5973tksft', 'Provider_TIN__c': 'a0FVF0000020PJp2AM', 'Group_Client__c': 'a0C8a00000r3NaREAU', 'Claim_Number__c': 'Z24320I1000048', 'Jurisdiction__c': 'a024W00000HYAjYQAX', 'Diag_Code__c': 'I998', 'Diag_Code_2nd__c': nan, 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'AGILE URGENT CARE ', 'Patient__c': 'NAGLE MATTHEW  ', 'Patient_ID__c': '135989137', 'Date_of_Birth__c': '01/02/1995', 'Provider_Zip__c': 70949998, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': nan, 'POS__c': 22, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 35: {'Claim_ID__c': 'DE5533AA4BF2469tksft', 'Provider_TIN__c': 'a0FVF0000020PLR2A2', 'Group_Client__c': 'a0C8a00000r3NZyEAM', 'Claim_Number__c': 'Z24320I1000099', 'Jurisdiction__c': 'a024W00000HYAjYQAX', 'Diag_Code__c': 'F1020', 'Diag_Code_2nd__c': nan, 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': '5034 ATLANTIC AVE OPCO LLC ', 'Patient__c': 'OCONNOR DANALYNN ', 'Patient_ID__c': '140587629', 'Date_of_Birth__c': '08/18/1978', 'Provider_Zip__c': 88792000, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': nan, 'POS__c': 22, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 36: {'Claim_ID__c': '0803C7C8BD18177tksft', 'Provider_TIN__c': 'a0FVF000001zh5t2AA', 'Group_Client__c': 'a0C8a00000r3GJ6EAM', 'Claim_Number__c': '431817310700005', 'Jurisdiction__c': 'a024W00000ICbumQAD', 'Diag_Code__c': 'M7521', 'Diag_Code_2nd__c': 'S29012D', 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'KAISER FOUNDATION HOSPITALS ', 'Patient__c': 'milton love  C', 'Patient_ID__c': '607983094', 'Date_of_Birth__c': '05/27/1997', 'Provider_Zip__c': 900749998, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': nan, 'POS__c': 13, 'Provider_Specialty__c': 'a008a000015yXODAA2', 'Service_Type__c': 'OUTPATIENT'}
# Processing record 37: {'Claim_ID__c': '6253B978E843533tksft', 'Provider_TIN__c': 'a0F4W00000W1H9WUAV', 'Group_Client__c': 'a0C8a000017cPdwEAE', 'Claim_Number__c': 'Z24318I1000029', 'Jurisdiction__c': 'a024W00000HYAjbQAH', 'Diag_Code__c': 'M25512', 'Diag_Code_2nd__c': nan, 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'HOSPITAL FOR SPECIAL SURGERY ', 'Patient__c': 'FARRELL BRENDAN  ', 'Patient_ID__c': '058889203', 'Date_of_Birth__c': '05/11/1998', 'Provider_Zip__c': 100879174, 'DRG__c': nan, 'QPA__c': 'Y', 'NPI__c': nan, 'POS__c': 22, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 38: {'Claim_ID__c': '72F78B589C1A559tksft', 'Provider_TIN__c': 'a0F4W00000W1KI2UAN', 'Group_Client__c': 'a0CUu00000BrjTqMAJ', 'Claim_Number__c': '243191734Q', 'Jurisdiction__c': 'a024W00000HYAjJQAX', 'Diag_Code__c': 'Z3800', 'Diag_Code_2nd__c': 'R509', 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'SULLIVAN COUNTY COMM HOSPITAL ', 'Patient__c': 'SNYDER CHARLES ', 'Patient_ID__c': '315211540', 'Date_of_Birth__c': '10/16/2024', 'Provider_Zip__c': 478827523, 'DRG__c': 'a014W00000ym0YfQAI', 'QPA__c': 'N', 'NPI__c': 1417585837.0, 'POS__c': 11, 'Provider_Specialty__c': 'a008a000015yXOFAA2', 'Service_Type__c': 'OUTPATIENT'}
# Processing record 39: {'Claim_ID__c': 'C9C36EC1AA4F547tksft', 'Provider_TIN__c': 'a0FVF0000020PN32AM', 'Group_Client__c': 'a0CUu000002byniMAA', 'Claim_Number__c': '725003590890', 'Jurisdiction__c': 'a024W00000HYAjQQAX', 'Diag_Code__c': 'S0990XA', 'Diag_Code_2nd__c': 'M542', 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'GRAND ITASCA CLINIC AND H ', 'Patient__c': 'GORRON WENDY ', 'Patient_ID__c': '999999999', 'Date_of_Birth__c': '01/16/1965', 'Provider_Zip__c': 554409998, 'DRG__c': nan, 'QPA__c': 'Y', 'NPI__c': nan, 'POS__c': 13, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 40: {'Claim_ID__c': '1A201AC88363FBEtksft', 'Provider_TIN__c': 'a0FVF000001zh5t2AA', 'Group_Client__c': 'a0C8a00000r3GJ6EAM', 'Claim_Number__c': '431817310700019', 'Jurisdiction__c': 'a024W00000ICbumQAD', 'Diag_Code__c': 'M5450', 'Diag_Code_2nd__c': nan, 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'KAISER FOUNDATION HOSPITALS ', 'Patient__c': 'Ford Nathan  ', 'Patient_ID__c': '611601304', 'Date_of_Birth__c': '01/08/1992', 'Provider_Zip__c': 900749998, 'DRG__c': nan, 'QPA__c': 'Y', 'NPI__c': nan, 'POS__c': 13, 'Provider_Specialty__c': 'a008a000015yXODAA2', 'Service_Type__c': 'OUTPATIENT'}
# Processing record 41: {'Claim_ID__c': 'C779152973796A4tksft', 'Provider_TIN__c': 'a0F4W00000W1KI2UAN', 'Group_Client__c': 'a0CUu00000BrjTqMAJ', 'Claim_Number__c': '243191647Q', 'Jurisdiction__c': 'a024W00000HYAjJQAX', 'Diag_Code__c': 'M47814', 'Diag_Code_2nd__c': nan, 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'SULLIVAN COUNTY COMM HOSPITAL ', 'Patient__c': 'SMITH MONICA ', 'Patient_ID__c': '315740664', 'Date_of_Birth__c': '10/08/1973', 'Provider_Zip__c': 478827523, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': 1194386573.0, 'POS__c': 13, 'Provider_Specialty__c': 'a008a000015yXOFAA2', 'Service_Type__c': 'OUTPATIENT'}
# Processing record 42: {'Claim_ID__c': '386B36ECC5A825Dtksft', 'Provider_TIN__c': 'a0FVF000001Zaw52AC', 'Group_Client__c': 'a0C8a000017cLiDEAU', 'Claim_Number__c': 'ECI001BVL22421344400', 'Jurisdiction__c': 'a024W00000ICbumQAD', 'Diag_Code__c': 'F1120', 'Diag_Code_2nd__c': nan, 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'WE LEVEL UP CALIFORNIA LLC ', 'Patient__c': 'TOOMBS JARRATT B', 'Patient_ID__c': '223047099', 'Date_of_Birth__c': '03/15/1974', 'Provider_Zip__c': 925304523, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': 1740546209.0, 'POS__c': 11, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 43: {'Claim_ID__c': '424A73E70768041tksft', 'Provider_TIN__c': 'a0F4W00000W1KI2UAN', 'Group_Client__c': 'a0CUu00000BrjTqMAJ', 'Claim_Number__c': '243191733Q', 'Jurisdiction__c': 'a024W00000HYAjJQAX', 'Diag_Code__c': 'P599', 'Diag_Code_2nd__c': nan, 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'SULLIVAN COUNTY COMM HOSPITAL ', 'Patient__c': 'SNYDER CHARLES ', 'Patient_ID__c': '315211540', 'Date_of_Birth__c': '10/16/2024', 'Provider_Zip__c': 478827523, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': 1912947169.0, 'POS__c': 13, 'Provider_Specialty__c': 'a008a000015yXOFAA2', 'Service_Type__c': 'OUTPATIENT'}
# Processing record 44: {'Claim_ID__c': '5D1776CEAF01028tksft', 'Provider_TIN__c': 'a0FVF000001ZbXB2A0', 'Group_Client__c': 'a0C8a00000r3Gf3EAE', 'Claim_Number__c': '243181904Q', 'Jurisdiction__c': 'a024W00000HYAjkQAH', 'Diag_Code__c': 'J189', 'Diag_Code_2nd__c': nan, 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'METHODIST GERMANTOWN HOSPITAL ', 'Patient__c': 'WILLIAMSON CHARLES ', 'Patient_ID__c': 'MB00789033', 'Date_of_Birth__c': '09/15/2013', 'Provider_Zip__c': 753732872, 'DRG__c': nan, 'QPA__c': 'Y', 'NPI__c': 1639497084.0, 'POS__c': 13, 'Provider_Specialty__c': 'a008a000015yXODAA2', 'Service_Type__c': 'OUTPATIENT'}
# Processing record 45: {'Claim_ID__c': '2DF6EF823DBD1A3tksft', 'Provider_TIN__c': 'a0FVF0000020Oqo2AE', 'Group_Client__c': 'a0C4W00000dJpXeUAK', 'Claim_Number__c': 'ECM2024101511145', 'Jurisdiction__c': 'a024W00000HYAjSQAX', 'Diag_Code__c': 'F1020', 'Diag_Code_2nd__c': 'F909', 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'DEFINING WELLNESS CENTERS INC ', 'Patient__c': 'MCEWEN STEWART ', 'Patient_ID__c': 'E10908048-01', 'Date_of_Birth__c': '08/20/1985', 'Provider_Zip__c': 390479998, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': nan, 'POS__c': 13, 'Provider_Specialty__c': 'a008a000015yXOrAAM', 'Service_Type__c': 'BEHAV HEALTH'}
# Processing record 46: {'Claim_ID__c': 'B17551A5CD4B233tksft', 'Provider_TIN__c': 'a0F4W00000W1LEEUA3', 'Group_Client__c': nan, 'Claim_Number__c': '18A91B0008179A8', 'Jurisdiction__c': 'a024W00000HYAjRQAX', 'Diag_Code__c': 'Z5181', 'Diag_Code_2nd__c': 'Z79899', 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'FREEMAN NEOSHO HOSPITAL ', 'Patient__c': 'WILSON ROBERT  L', 'Patient_ID__c': '880440969', 'Date_of_Birth__c': '03/12/1960', 'Provider_Zip__c': 648501705, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': 1154989564.0, 'POS__c': 85, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Error during insert: Malformed request https://relianthealthpartners2020--tctdev.sandbox.my.salesforce.com/services/data/v59.0/sobjects/Claims__c/. Response content: [{'message': 'Required fields are missing: [Group_Client__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['Group_Client__c']}]
# Processing record 47: {'Claim_ID__c': 'F07FADD7D020ECDtksft', 'Provider_TIN__c': 'a0FVF0000020POf2AM', 'Group_Client__c': 'a0C8a00000r3NZyEAM', 'Claim_Number__c': 'Z24320I1000001', 'Jurisdiction__c': 'a024W00000HYAjfQAH', 'Diag_Code__c': 'F1210', 'Diag_Code_2nd__c': nan, 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'HOBOKEN UMC ', 'Patient__c': 'LORENZANA ANIAH ', 'Patient_ID__c': '140767215', 'Date_of_Birth__c': '12/27/2007', 'Provider_Zip__c': 191824491, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': nan, 'POS__c': 22, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 48: {'Claim_ID__c': 'D89CA202DDCF42Ctksft', 'Provider_TIN__c': 'a0F4W00000W1KI2UAN', 'Group_Client__c': 'a0CUu00000BrjTqMAJ', 'Claim_Number__c': '243191635Q', 'Jurisdiction__c': 'a024W00000HYAjJQAX', 'Diag_Code__c': 'L600', 'Diag_Code_2nd__c': 'R2242', 'Diag_Code_3rd__c': 'M79672', 'Diag_Code_4th__c': 'M79671', 'Provider__c': 'SULLIVAN COUNTY COMM HOSPITAL ', 'Patient__c': 'CALLISON DAKOTA ', 'Patient_ID__c': '313065368', 'Date_of_Birth__c': '07/10/2010', 'Provider_Zip__c': 478827523, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': 1639605637.0, 'POS__c': 13, 'Provider_Specialty__c': 'a008a000015yXOFAA2', 'Service_Type__c': 'OUTPATIENT'}
# Processing record 49: {'Claim_ID__c': '24BF09BD7288E97tksft', 'Provider_TIN__c': 'a0FVF0000020PQH2A2', 'Group_Client__c': nan, 'Claim_Number__c': '06A11B00081784F', 'Jurisdiction__c': 'a024W00000HYAjkQAH', 'Diag_Code__c': 'M25532', 'Diag_Code_2nd__c': 'X500XXA', 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'PFLUGERVILLE EMERGENCY CENTER LLC ', 'Patient__c': 'INABINETT COLE ', 'Patient_ID__c': '750076498', 'Date_of_Birth__c': '05/27/2011', 'Provider_Zip__c': 786605965, 'DRG__c': nan, 'QPA__c': 'Y', 'NPI__c': 1154761971.0, 'POS__c': 13, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Error during insert: Malformed request https://relianthealthpartners2020--tctdev.sandbox.my.salesforce.com/services/data/v59.0/sobjects/Claims__c/. Response content: [{'message': 'Required fields are missing: [Group_Client__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['Group_Client__c']}]
# Processing record 50: {'Claim_ID__c': '4A0DB6FA37D50B4tksft', 'Provider_TIN__c': 'a0FVF000001zh5t2AA', 'Group_Client__c': 'a0C8a00000r3GJ6EAM', 'Claim_Number__c': '431717305300007', 'Jurisdiction__c': 'a024W00000ICbumQAD', 'Diag_Code__c': 'T8142XA', 'Diag_Code_2nd__c': 'R509', 'Diag_Code_3rd__c': 'Y92019', 'Diag_Code_4th__c': 'A4101', 'Provider__c': 'KAISER FOUNDATION HOSPITALS ', 'Patient__c': 'WILSON SCOTT  ', 'Patient_ID__c': '549951424', 'Date_of_Birth__c': '12/03/1975', 'Provider_Zip__c': 900749998, 'DRG__c': 'a014W00000ym0ZdQAI', 'QPA__c': 'Y', 'NPI__c': nan, 'POS__c': 11, 'Provider_Specialty__c': 'a008a000015yXODAA2', 'Service_Type__c': 'OUTPATIENT'}
# Processing record 51: {'Claim_ID__c': 'E2E929EB65CD595tksft', 'Provider_TIN__c': 'a0FVF000001zh5t2AA', 'Group_Client__c': 'a0C8a00000r3GJ6EAM', 'Claim_Number__c': '431817310700003', 'Jurisdiction__c': 'a024W00000ICbumQAD', 'Diag_Code__c': 'S61210A', 'Diag_Code_2nd__c': 'W268XXA', 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'KAISER FOUNDATION HOSPITALS ', 'Patient__c': 'Mendez Luis  ', 'Patient_ID__c': '613101444', 'Date_of_Birth__c': '03/29/1988', 'Provider_Zip__c': 900749998, 'DRG__c': nan, 'QPA__c': 'Y', 'NPI__c': nan, 'POS__c': 13, 'Provider_Specialty__c': 'a008a000015yXODAA2', 'Service_Type__c': 'OUTPATIENT'}
# Processing record 52: {'Claim_ID__c': 'D6ED7E3B9E6753Ftksft', 'Provider_TIN__c': 'a0FVF000001Zaw52AC', 'Group_Client__c': 'a0C8a000017cLiDEAU', 'Claim_Number__c': 'ECI001BVL22421344700', 'Jurisdiction__c': 'a024W00000ICbumQAD', 'Diag_Code__c': 'F1120', 'Diag_Code_2nd__c': nan, 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'WE LEVEL UP CALIFORNIA LLC ', 'Patient__c': 'TOOMBS JARRATT B', 'Patient_ID__c': '223047099', 'Date_of_Birth__c': '03/15/1974', 'Provider_Zip__c': 925304523, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': 1740546209.0, 'POS__c': 11, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 53: {'Claim_ID__c': 'EAAE3F3597917A8tksft', 'Provider_TIN__c': 'a0FVF0000020P8X2AU', 'Group_Client__c': 'a0C8a00000r3NZyEAM', 'Claim_Number__c': 'Z24320I1000071', 'Jurisdiction__c': 'a024W00000HYAjDQAX', 'Diag_Code__c': 'F3189', 'Diag_Code_2nd__c': 'F411', 'Diag_Code_3rd__c': 'F4310', 'Diag_Code_4th__c': 'F1020', 'Provider__c': 'DEERFIELD FLORIDA HOUSE INC ', 'Patient__c': 'FRANCOLINO FRANK  ', 'Patient_ID__c': '154568840', 'Date_of_Birth__c': '05/05/1972', 'Provider_Zip__c': 334414117, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': nan, 'POS__c': 22, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 54: {'Claim_ID__c': '0471E3313C6ED47tksft', 'Provider_TIN__c': 'a0FVF000001Zaw52AC', 'Group_Client__c': 'a0C8a000017cLiDEAU', 'Claim_Number__c': 'ECI001BVL22421344800', 'Jurisdiction__c': 'a024W00000ICbumQAD', 'Diag_Code__c': 'F1120', 'Diag_Code_2nd__c': nan, 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'WE LEVEL UP CALIFORNIA LLC ', 'Patient__c': 'TOOMBS JARRATT B', 'Patient_ID__c': '223047099', 'Date_of_Birth__c': '03/15/1974', 'Provider_Zip__c': 925304523, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': 1740546209.0, 'POS__c': 11, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 55: {'Claim_ID__c': '0528EDA1B036829tksft', 'Provider_TIN__c': 'a0FVF0000020PLS2A2', 'Group_Client__c': 'a0C8a00000r3Gf3EAE', 'Claim_Number__c': '243180366Q', 'Jurisdiction__c': 'a024W00000HYAjDQAX', 'Diag_Code__c': 'F1320', 'Diag_Code_2nd__c': 'F1120', 'Diag_Code_3rd__c': 'F1220', 'Diag_Code_4th__c': 'F1620', 'Provider__c': 'TREATMENT CENTERS OF AMERICA LLC ', 'Patient__c': 'REED ANNA ', 'Patient_ID__c': 'MB00413159', 'Date_of_Birth__c': '12/19/1997', 'Provider_Zip__c': 347854230, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': 1841227634.0, 'POS__c': 11, 'Provider_Specialty__c': 'a008a000015yXOrAAM', 'Service_Type__c': 'BEHAV HEALTH'}
# Processing record 56: {'Claim_ID__c': '09720353DAA3DC5tksft', 'Provider_TIN__c': 'a0FVF0000020PRt2AM', 'Group_Client__c': 'a0C8a000017cPe1EAE', 'Claim_Number__c': 'Z24317I1000145', 'Jurisdiction__c': 'a024W00000ICburQAD', 'Diag_Code__c': 'K219', 'Diag_Code_2nd__c': nan, 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'STAMFORD ', 'Patient__c': 'PARIETARIO NELLA ', 'Patient_ID__c': '048847030', 'Date_of_Birth__c': '09/03/1971', 'Provider_Zip__c': 69024501, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': nan, 'POS__c': 24, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 57: {'Claim_ID__c': '0C7171CC746A405tksft', 'Provider_TIN__c': 'a0FVF0000020PTV2A2', 'Group_Client__c': 'a0C8a00000r3PoMEAU', 'Claim_Number__c': 'Z24320I1000002', 'Jurisdiction__c': 'a024W00000HYAjfQAH', 'Diag_Code__c': 'Z5112', 'Diag_Code_2nd__c': 'C642', 'Diag_Code_3rd__c': 'C7989', 'Diag_Code_4th__c': 'C771', 'Provider__c': 'TUH FOX CHASE ', 'Patient__c': 'MANN PRADEEP  ', 'Patient_ID__c': '426537784', 'Date_of_Birth__c': '02/08/1975', 'Provider_Zip__c': 191112434, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': nan, 'POS__c': 22, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 58: {'Claim_ID__c': '22E9B9DF3B712B7tksft', 'Provider_TIN__c': 'a0FVF000001Zaw52AC', 'Group_Client__c': 'a0C8a000017cLiDEAU', 'Claim_Number__c': 'ECI001BVL22421345100', 'Jurisdiction__c': 'a024W00000ICbumQAD', 'Diag_Code__c': 'F1120', 'Diag_Code_2nd__c': nan, 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'WE LEVEL UP CALIFORNIA LLC ', 'Patient__c': 'TOOMBS JARRATT B', 'Patient_ID__c': '223047099', 'Date_of_Birth__c': '03/15/1974', 'Provider_Zip__c': 925304523, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': 1740546209.0, 'POS__c': 11, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 59: {'Claim_ID__c': 'ED523330AD7A9EAtksft', 'Provider_TIN__c': 'a0FVF000001Zb902AC', 'Group_Client__c': 'a0C8a00000r3Na7EAE', 'Claim_Number__c': 'A24317I1000002', 'Jurisdiction__c': 'a024W00000HYAjYQAX', 'Diag_Code__c': 'F1520', 'Diag_Code_2nd__c': 'F1010', 'Diag_Code_3rd__c': 'F331', 'Diag_Code_4th__c': 'F4312', 'Provider__c': 'KINGSWAY RECOVERY LLC ', 'Patient__c': 'LENKOWSKI MARIE  ', 'Patient_ID__c': '151568752', 'Date_of_Birth__c': '02/03/1959', 'Provider_Zip__c': 80621234, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': nan, 'POS__c': 22, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 60: {'Claim_ID__c': '701E10C9529F727tksft', 'Provider_TIN__c': 'a0FVF0000020PV72AM', 'Group_Client__c': 'a0C8a00000r3G8IEAU', 'Claim_Number__c': '432005414600011', 'Jurisdiction__c': 'a024W00000HYAjbQAH', 'Diag_Code__c': 'M5416', 'Diag_Code_2nd__c': nan, 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'SPECIALISTS ONE DAY SURGERY ', 'Patient__c': 'ALARCO CHRISTOPHER L', 'Patient_ID__c': '261965234', 'Date_of_Birth__c': '10/03/1998', 'Provider_Zip__c': 132149998, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': 1639261365.0, 'POS__c': 83, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 61: {'Claim_ID__c': '6841850D0084E30tksft', 'Provider_TIN__c': 'a0F4W00000W1KI2UAN', 'Group_Client__c': 'a0CUu00000BrjTqMAJ', 'Claim_Number__c': '243191732Q', 'Jurisdiction__c': 'a024W00000HYAjJQAX', 'Diag_Code__c': 'P599', 'Diag_Code_2nd__c': nan, 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'SULLIVAN COUNTY COMM HOSPITAL ', 'Patient__c': 'SNYDER CHARLES ', 'Patient_ID__c': '315211540', 'Date_of_Birth__c': '10/16/2024', 'Provider_Zip__c': 478827523, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': 1912947169.0, 'POS__c': 13, 'Provider_Specialty__c': 'a008a000015yXOFAA2', 'Service_Type__c': 'OUTPATIENT'}
# Processing record 62: {'Claim_ID__c': '078C3C90D1273BDtksft', 'Provider_TIN__c': 'a0F4W00000W1HQ7UAN', 'Group_Client__c': 'a0C8a00000r3NZxEAM', 'Claim_Number__c': 'Z24318I1000070', 'Jurisdiction__c': 'a024W00000HYAjYQAX', 'Diag_Code__c': 'F4310', 'Diag_Code_2nd__c': 'F3181', 'Diag_Code_3rd__c': 'F1020', 'Diag_Code_4th__c': nan, 'Provider__c': 'THE COUNSELING CENTER AT CLARK ', 'Patient__c': 'WEHRHAHN KRIS  ', 'Patient_ID__c': '147800277', 'Date_of_Birth__c': '02/14/1978', 'Provider_Zip__c': 71011234, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': nan, 'POS__c': 22, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 63: {'Claim_ID__c': 'C27EA1D81BD0DB9tksft', 'Provider_TIN__c': 'a0FVF000001Zaw52AC', 'Group_Client__c': 'a0C8a000017cLiDEAU', 'Claim_Number__c': 'ECI001BVL22421345200', 'Jurisdiction__c': 'a024W00000ICbumQAD', 'Diag_Code__c': 'F1120', 'Diag_Code_2nd__c': nan, 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'WE LEVEL UP CALIFORNIA LLC ', 'Patient__c': 'TOOMBS JARRATT B', 'Patient_ID__c': '223047099', 'Date_of_Birth__c': '03/15/1974', 'Provider_Zip__c': 925304523, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': 1740546209.0, 'POS__c': 11, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 64: {'Claim_ID__c': '343A5F86C2346CEtksft', 'Provider_TIN__c': 'a0FVF000001ZbXB2A0', 'Group_Client__c': 'a0C8a00000r3Gf3EAE', 'Claim_Number__c': '243172157Q', 'Jurisdiction__c': 'a024W00000HYAjkQAH', 'Diag_Code__c': 'R0602', 'Diag_Code_2nd__c': 'Z8774', 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'LE BONHEUR CHILDRENS HOSPITAL ', 'Patient__c': 'KIRK REESE ', 'Patient_ID__c': 'MB00510849', 'Date_of_Birth__c': '01/22/2013', 'Provider_Zip__c': 753732872, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': 1194905000.0, 'POS__c': 13, 'Provider_Specialty__c': 'a008a000015yXOEAA2', 'Service_Type__c': 'OUTPATIENT'}
# Processing record 65: {'Claim_ID__c': '2BCA5EB7AB0AC22tksft', 'Provider_TIN__c': 'a0F4W00000W1KI2UAN', 'Group_Client__c': 'a0CUu00000BrjTqMAJ', 'Claim_Number__c': '243191633Q', 'Jurisdiction__c': 'a024W00000HYAjJQAX', 'Diag_Code__c': 'Z01419', 'Diag_Code_2nd__c': 'R5383', 'Diag_Code_3rd__c': 'Z1331', 'Diag_Code_4th__c': nan, 'Provider__c': 'SULLIVAN COUNTY COMM HOSPITAL ', 'Patient__c': 'WHITE HANNAH ', 'Patient_ID__c': '316159605', 'Date_of_Birth__c': '03/18/1990', 'Provider_Zip__c': 478827523, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': 1851353866.0, 'POS__c': 13, 'Provider_Specialty__c': 'a008a000015yXOFAA2', 'Service_Type__c': 'OUTPATIENT'}
# Processing record 66: {'Claim_ID__c': '7C912A71A5D7D8Atksft', 'Provider_TIN__c': 'a0F4W00000W1LmPUAV', 'Group_Client__c': 'a0C8a00000r3G8IEAU', 'Claim_Number__c': '431705422700003', 'Jurisdiction__c': 'a024W00000HYAjlQAH', 'Diag_Code__c': 'S8001XA', 'Diag_Code_2nd__c': nan, 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'INTERMOUNTAIN MEDICAL CENTER ', 'Patient__c': 'MCBRIDE ASHLYN ', 'Patient_ID__c': '876000497', 'Date_of_Birth__c': '07/18/1999', 'Provider_Zip__c': 841309998, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': 1043220650.0, 'POS__c': 13, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 67: {'Claim_ID__c': '5E770C9E870ADBCtksft', 'Provider_TIN__c': 'a0FVF0000020P8X2AU', 'Group_Client__c': 'a0C8a00000r3NZyEAM', 'Claim_Number__c': 'Z24320I1000069', 'Jurisdiction__c': 'a024W00000HYAjDQAX', 'Diag_Code__c': 'F332', 'Diag_Code_2nd__c': 'F4310', 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'DEERFIELD FLORIDA HOUSE INC ', 'Patient__c': 'BATES DAMIEN  ', 'Patient_ID__c': '156861764', 'Date_of_Birth__c': '07/26/1989', 'Provider_Zip__c': 334414117, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': nan, 'POS__c': 21, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 68: {'Claim_ID__c': '0D8755A2AD0EBC0tksft', 'Provider_TIN__c': 'a0FVF0000020Onc2AE', 'Group_Client__c': nan, 'Claim_Number__c': 'P24319I2000001', 'Jurisdiction__c': 'a024W00000HYAjRQAX', 'Diag_Code__c': 'Z01818', 'Diag_Code_2nd__c': 'N871', 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'CURATORS OF THE UNIVERSITY ', 'Patient__c': 'ARNOLD ASHLEY  ', 'Patient_ID__c': '489984314', 'Date_of_Birth__c': '05/19/1988', 'Provider_Zip__c': 652120001, 'DRG__c': nan, 'QPA__c': 'Y', 'NPI__c': nan, 'POS__c': 22, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Error during insert: Malformed request https://relianthealthpartners2020--tctdev.sandbox.my.salesforce.com/services/data/v59.0/sobjects/Claims__c/. Response content: [{'message': 'Required fields are missing: [Group_Client__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['Group_Client__c']}]
# Processing record 69: {'Claim_ID__c': '14047BE3838E09Atksft', 'Provider_TIN__c': 'a0FVF0000020P6v2AE', 'Group_Client__c': 'a0C8a00000r3NaaEAE', 'Claim_Number__c': 'A24318I1000001', 'Jurisdiction__c': 'a024W00000HYAjOQAX', 'Diag_Code__c': 'K5721', 'Diag_Code_2nd__c': 'K659', 'Diag_Code_3rd__c': 'K219', 'Diag_Code_4th__c': 'Z5331', 'Provider__c': 'EASTERN MAINE MEDICAL CENTER ', 'Patient__c': 'OSMAN TIMOTHY  ', 'Patient_ID__c': '172644585', 'Date_of_Birth__c': '01/06/1968', 'Provider_Zip__c': 44121006, 'DRG__c': 'a014W00000ym0S6QAI', 'QPA__c': 'Y', 'NPI__c': nan, 'POS__c': 21, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 70: {'Claim_ID__c': '0510C8BAA382B51tksft', 'Provider_TIN__c': 'a0FVF000001ZbXB2A0', 'Group_Client__c': 'a0C8a00000r3Gf3EAE', 'Claim_Number__c': '243181925Q', 'Jurisdiction__c': 'a024W00000HYAjkQAH', 'Diag_Code__c': 'J45901', 'Diag_Code_2nd__c': 'T162XXA', 'Diag_Code_3rd__c': 'H6505', 'Diag_Code_4th__c': nan, 'Provider__c': 'LE BONHEUR CHILDRENS HOSPITAL ', 'Patient__c': 'LOGGINS RIVER ', 'Patient_ID__c': 'MB04622977', 'Date_of_Birth__c': '04/19/2019', 'Provider_Zip__c': 753732872, 'DRG__c': nan, 'QPA__c': 'Y', 'NPI__c': 1952614570.0, 'POS__c': 13, 'Provider_Specialty__c': 'a008a000015yXOEAA2', 'Service_Type__c': 'OUTPATIENT'}
# Processing record 71: {'Claim_ID__c': '41201E1660A198Etksft', 'Provider_TIN__c': 'a0FVF0000020PWj2AM', 'Group_Client__c': 'a0C8a00000r3NaBEAU', 'Claim_Number__c': 'Z24318I1000098', 'Jurisdiction__c': 'a024W00000HYAjgQAH', 'Diag_Code__c': 'F1120', 'Diag_Code_2nd__c': nan, 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'CENTRAL JERSEY COMPREHENSIVE TREART ', 'Patient__c': 'NAPPI ROXANNE  ', 'Patient_ID__c': '105563660', 'Date_of_Birth__c': '02/04/1970', 'Provider_Zip__c': 29051522, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': nan, 'POS__c': 24, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 72: {'Claim_ID__c': 'C6F6144621EAC02tksft', 'Provider_TIN__c': 'a0FVF0000020PBl2AM', 'Group_Client__c': 'a0C8a00000r3NZxEAM', 'Claim_Number__c': 'Z24318I1000096', 'Jurisdiction__c': 'a024W00000ICbumQAD', 'Diag_Code__c': 'F1320', 'Diag_Code_2nd__c': 'F13239', 'Diag_Code_3rd__c': 'F1420', 'Diag_Code_4th__c': 'F1423', 'Provider__c': 'LEGACY HEALING CENTER CALIFORNIA ', 'Patient__c': 'RUBINO MARGARET  ', 'Patient_ID__c': '155583644', 'Date_of_Birth__c': '12/15/1962', 'Provider_Zip__c': 900461741, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': nan, 'POS__c': 21, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# ...
# Processing record 85: {'Claim_ID__c': 'B3CF8871C6B0019tksft', 'Provider_TIN__c': 'a0F4W00000W1KI2UAN', 'Group_Client__c': 'a0CUu00000BrjTqMAJ', 'Claim_Number__c': '243191648Q', 'Jurisdiction__c': 'a024W00000HYAjJQAX', 'Diag_Code__c': 'M51360', 'Diag_Code_2nd__c': nan, 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'SULLIVAN COUNTY COMM HOSPITAL ', 'Patient__c': 'GIBBS MICAH  D', 'Patient_ID__c': '306271916', 'Date_of_Birth__c': '05/31/2003', 'Provider_Zip__c': 478827523, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': 1326028309.0, 'POS__c': 13, 'Provider_Specialty__c': 'a008a000015yXOFAA2', 'Service_Type__c': 'OUTPATIENT'}
# Processing record 86: {'Claim_ID__c': '0B46B602A7B3B67tksft', 'Provider_TIN__c': 'a0FVF0000020PbZ2AU', 'Group_Client__c': nan, 'Claim_Number__c': '21040838Accredited', 'Jurisdiction__c': 'a024W00000HYAj9QAH', 'Diag_Code__c': 'M5416', 'Diag_Code_2nd__c': nan, 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'SURGCENTER NORTHERN PHOENIX ', 'Patient__c': 'PEN KEVIN  ', 'Patient_ID__c': 'XXXXX1120', 'Date_of_Birth__c': '11/22/1981', 'Provider_Zip__c': 850859998, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': nan, 'POS__c': 83, 'Provider_Specialty__c': 'a008a000015yXNEAA2', 'Service_Type__c': 'SURGERY CENTER'}
# Error during insert: Malformed request https://relianthealthpartners2020--tctdev.sandbox.my.salesforce.com/services/data/v59.0/sobjects/Claims__c/. Response content: [{'message': 'Required fields are missing: [Group_Client__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['Group_Client__c']}]
# Processing record 87: {'Claim_ID__c': '7544853707AB942tksft', 'Provider_TIN__c': 'a0F4W00000W1JN2UAN', 'Group_Client__c': 'a0C8a00000r3Gf3EAE', 'Claim_Number__c': '243182418Q', 'Jurisdiction__c': 'a024W00000HYAjjQAH', 'Diag_Code__c': 'K219', 'Diag_Code_2nd__c': 'R0789', 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'GI CENTER MIDSOUTH ', 'Patient__c': 'MAHARREY CHARLES  H', 'Patient_ID__c': 'MB00027211', 'Date_of_Birth__c': '10/09/1946', 'Provider_Zip__c': 381381741, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': 1437134020.0, 'POS__c': 83, 'Provider_Specialty__c': 'a008a000015yXNPAA2', 'Service_Type__c': 'SURGERY CENTER'}
# Processing record 88: {'Claim_ID__c': 'CF2723BDAA8444Atksft', 'Provider_TIN__c': 'a0F8a00001RfjwMEAR', 'Group_Client__c': 'a0C8a00000r3GJ6EAM', 'Claim_Number__c': '431917303900063', 'Jurisdiction__c': 'a024W00000HYAjUQAX', 'Diag_Code__c': 'S61214A', 'Diag_Code_2nd__c': 'W268XXA', 'Diag_Code_3rd__c': 'F17210', 'Diag_Code_4th__c': 'Z23', 'Provider__c': 'UNC ROCKINGHAM HEALTH CARE ', 'Patient__c': 'Via Sarah  ', 'Patient_ID__c': '243853637', 'Date_of_Birth__c': '04/13/1997', 'Provider_Zip__c': 282639998, 'DRG__c': nan, 'QPA__c': 'Y', 'NPI__c': nan, 'POS__c': 13, 'Provider_Specialty__c': 'a008a000015yXODAA2', 'Service_Type__c': 'OUTPATIENT'}
# Processing record 89: {'Claim_ID__c': '4AF88BA36C4D76Etksft', 'Provider_TIN__c': 'a0FVF000001zh5t2AA', 'Group_Client__c': 'a0C8a00000r3GJ6EAM', 'Claim_Number__c': '431817310700007', 'Jurisdiction__c': 'a024W00000ICbumQAD', 'Diag_Code__c': 'S62606A', 'Diag_Code_2nd__c': 'M85841', 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'KAISER FOUNDATION HOSPITALS ', 'Patient__c': 'Silveira Nancy  ', 'Patient_ID__c': '546088812', 'Date_of_Birth__c': '08/28/1963', 'Provider_Zip__c': 900749998, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': nan, 'POS__c': 13, 'Provider_Specialty__c': 'a008a000015yXODAA2', 'Service_Type__c': 'OUTPATIENT'}
# Processing record 90: {'Claim_ID__c': '6702E0C9E929C49tksft', 'Provider_TIN__c': 'a0FVF0000020PEz2AM', 'Group_Client__c': 'a0C8a00000r3NaUEAU', 'Claim_Number__c': 'Z24320I1000026', 'Jurisdiction__c': 'a024W00000ICburQAD', 'Diag_Code__c': 'F332', 'Diag_Code_2nd__c': nan, 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'CT CLINICAL SERVICES INC ', 'Patient__c': 'OCONNOR DILELLO KATHLEEN ', 'Patient_ID__c': '148769413', 'Date_of_Birth__c': '04/08/2008', 'Provider_Zip__c': 65102014, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': nan, 'POS__c': 55, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 91: {'Claim_ID__c': '1EC3C8897F7D906tksft', 'Provider_TIN__c': 'a0FVF000001Zaw52AC', 'Group_Client__c': 'a0C8a000017cLiDEAU', 'Claim_Number__c': 'ECI001BVL22421345500', 'Jurisdiction__c': 'a024W00000ICbumQAD', 'Diag_Code__c': 'F1120', 'Diag_Code_2nd__c': nan, 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'WE LEVEL UP CALIFORNIA LLC ', 'Patient__c': 'TOOMBS JARRATT B', 'Patient_ID__c': '223047099', 'Date_of_Birth__c': '03/15/1974', 'Provider_Zip__c': 925304523, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': 1740546209.0, 'POS__c': 11, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 92: {'Claim_ID__c': '967DBA61D10D7F4tksft', 'Provider_TIN__c': 'a0FVF0000020PBl2AM', 'Group_Client__c': 'a0C8a00000r3NZxEAM', 'Claim_Number__c': 'Z24318I1000087', 'Jurisdiction__c': 'a024W00000ICbumQAD', 'Diag_Code__c': 'F1320', 'Diag_Code_2nd__c': 'F13239', 'Diag_Code_3rd__c': 'F1420', 'Diag_Code_4th__c': 'F1423', 'Provider__c': 'LEGACY HEALING CENTER CALIFORNIA ', 'Patient__c': 'RUBINO MARGARET  ', 'Patient_ID__c': '155583644', 'Date_of_Birth__c': '12/15/1962', 'Provider_Zip__c': 900461741, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': nan, 'POS__c': 21, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 93: {'Claim_ID__c': '0A0F8F6C224006Atksft', 'Provider_TIN__c': 'a0F4W00000W1K3RUAV', 'Group_Client__c': 'a0C8a00000r3KpvEAE', 'Claim_Number__c': '243192214Q', 'Jurisdiction__c': 'a024W00000HYAjcQAH', 'Diag_Code__c': 'R002', 'Diag_Code_2nd__c': 'R079', 'Diag_Code_3rd__c': 'Z8249', 'Diag_Code_4th__c': 'Z136', 'Provider__c': 'CHILDRENS HOS MED CTR CH ', 'Patient__c': 'BROWN HARRISON ', 'Patient_ID__c': '285907262', 'Date_of_Birth__c': '01/30/2017', 'Provider_Zip__c': 452293039, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': 1730278391.0, 'POS__c': 13, 'Provider_Specialty__c': 'a008a000015yXOEAA2', 'Service_Type__c': 'OUTPATIENT'}
# Processing record 94: {'Claim_ID__c': '21CAA40376F3071tksft', 'Provider_TIN__c': 'a0F8a00001RfiLNEAZ', 'Group_Client__c': 'a0C8a00000r3GJ6EAM', 'Claim_Number__c': '431917303900077', 'Jurisdiction__c': 'a024W00000HYAjDQAX', 'Diag_Code__c': 'M5459', 'Diag_Code_2nd__c': 'M47896', 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'COMPREHENSIVE SURGERY CENTER LLC ', 'Patient__c': 'Warren Donnie  ', 'Patient_ID__c': '264274059', 'Date_of_Birth__c': '03/22/1956', 'Provider_Zip__c': 337659998, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': nan, 'POS__c': 83, 'Provider_Specialty__c': 'a008a000015yXODAA2', 'Service_Type__c': 'OUTPATIENT'}
# Processing record 95: {'Claim_ID__c': '779EBFBA320331Btksft', 'Provider_TIN__c': 'a0FVF000001zh5t2AA', 'Group_Client__c': 'a0C8a00000r3GJ6EAM', 'Claim_Number__c': '431817310700023', 'Jurisdiction__c': 'a024W00000ICbumQAD', 'Diag_Code__c': 'K429', 'Diag_Code_2nd__c': nan, 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'KAISER FOUNDATION HOSPITALS ', 'Patient__c': 'Lynch Jaydon  ', 'Patient_ID__c': '615476596', 'Date_of_Birth__c': '09/24/2004', 'Provider_Zip__c': 900749998, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': nan, 'POS__c': 13, 'Provider_Specialty__c': 'a008a000015yXODAA2', 'Service_Type__c': 'OUTPATIENT'}
# Processing record 96: {'Claim_ID__c': '35516B876AC4D90tksft', 'Provider_TIN__c': 'a0FVF000001f3hJ2AQ', 'Group_Client__c': 'a0CUu00000BrjTqMAJ', 'Claim_Number__c': '243192458Q', 'Jurisdiction__c': 'a024W00000HYAjIQAX', 'Diag_Code__c': 'R000', 'Diag_Code_2nd__c': 'R42', 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'LAWRENCE COUNTY MEMORIAL HOSPI ', 'Patient__c': 'MAYS FELICITY ', 'Patient_ID__c': '316069645', 'Date_of_Birth__c': '08/10/2012', 'Provider_Zip__c': 624391899, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': 1346449188.0, 'POS__c': 13, 'Provider_Specialty__c': 'a008a000015yXOFAA2', 'Service_Type__c': 'OUTPATIENT'}
# Processing record 97: {'Claim_ID__c': '6A238668984032Ftksft', 'Provider_TIN__c': 'a0FVF0000020PLS2A2', 'Group_Client__c': 'a0C8a00000r3Gf3EAE', 'Claim_Number__c': '243180367Q', 'Jurisdiction__c': 'a024W00000HYAjDQAX', 'Diag_Code__c': 'F1320', 'Diag_Code_2nd__c': 'F1120', 'Diag_Code_3rd__c': 'F1220', 'Diag_Code_4th__c': 'F1620', 'Provider__c': 'TREATMENT CENTERS OF AMERICA LLC ', 'Patient__c': 'REED ANNA ', 'Patient_ID__c': 'MB00413159', 'Date_of_Birth__c': '12/19/1997', 'Provider_Zip__c': 347854230, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': 1841227634.0, 'POS__c': 11, 'Provider_Specialty__c': 'a008a000015yXOrAAM', 'Service_Type__c': 'BEHAV HEALTH'}
# Processing record 98: {'Claim_ID__c': 'B1811ECF38F80B9tksft', 'Provider_TIN__c': 'a0FVF0000020PdB2AU', 'Group_Client__c': 'a0C8a00000r3G8IEAU', 'Claim_Number__c': '432005414600003', 'Jurisdiction__c': 'a024W00000HYAjbQAH', 'Diag_Code__c': 'S46012A', 'Diag_Code_2nd__c': 'M65812', 'Diag_Code_3rd__c': 'M24111', 'Diag_Code_4th__c': 'M7542', 'Provider__c': 'HUDSON VALLEY AMBULATORY SURGE ', 'Patient__c': 'GILBERT-MANN DEBORAH L', 'Patient_ID__c': '141739366', 'Date_of_Birth__c': '01/25/1966', 'Provider_Zip__c': 109419998, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': 1598789141.0, 'POS__c': 83, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 99: {'Claim_ID__c': '931B42FBF252672tksft', 'Provider_TIN__c': 'a0FVF000001Zb8z2AC', 'Group_Client__c': 'a0CUu00000BrjTqMAJ', 'Claim_Number__c': '243182566Q', 'Jurisdiction__c': 'a024W00000HYAjJQAX', 'Diag_Code__c': 'Z319', 'Diag_Code_2nd__c': nan, 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'UNION HOSPITAL ', 'Patient__c': 'KENDALL MASON  L', 'Patient_ID__c': '304216446', 'Date_of_Birth__c': '09/16/1998', 'Provider_Zip__c': 462060589, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': 1205944238.0, 'POS__c': 13, 'Provider_Specialty__c': 'a008a000015yXODAA2', 'Service_Type__c': 'OUTPATIENT'}
# Processing record 100: {'Claim_ID__c': '1F004304F91A53Dtksft', 'Provider_TIN__c': 'a0F4W00000W1KYKUA3', 'Group_Client__c': 'a0CUu000003Sk4jMAC', 'Claim_Number__c': 'E8AB1B000810EE7', 'Jurisdiction__c': 'a024W00000HYAjVQAX', 'Diag_Code__c': 'E559', 'Diag_Code_2nd__c': 'Z0000', 'Diag_Code_3rd__c': 'Z13220', 'Diag_Code_4th__c': nan, 'Provider__c': 'MCKENZIE COUNTY HEALTHCARE ', 'Patient__c': 'GONSALEZ ESTHER  ', 'Patient_ID__c': '763180114', 'Date_of_Birth__c': '05/08/1980', 'Provider_Zip__c': 588547628, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': nan, 'POS__c': 13, 'Provider_Specialty__c': 'a008a000015yXCSAA2', 'Service_Type__c': 'PHYSICIAN'}
# Processing record 101: {'Claim_ID__c': 'CC35F9FD23B19BFtksft', 'Provider_TIN__c': 'a0F4W00000W1JAgUAN', 'Group_Client__c': 'a0C8a00000r3KpvEAE', 'Claim_Number__c': '243191649Q', 'Jurisdiction__c': 'a024W00000HYAjKQAX', 'Diag_Code__c': 'T18128A', 'Diag_Code_2nd__c': nan, 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'ST. ELIZABETH FLORENCE ', 'Patient__c': 'KLETTE CADEN ', 'Patient_ID__c': '404087982', 'Date_of_Birth__c': '11/18/2009', 'Provider_Zip__c': 410424824, 'DRG__c': nan, 'QPA__c': 'Y', 'NPI__c': 1104288190.0, 'POS__c': 13, 'Provider_Specialty__c': 'a008a000015yXODAA2', 'Service_Type__c': 'OUTPATIENT'}
# Processing record 102: {'Claim_ID__c': 'B383E06344E8830tksft', 'Provider_TIN__c': 'a0F4W00000W1KR6UAN', 'Group_Client__c': 'a0C8a00000r3Gf3EAE', 'Claim_Number__c': '243190941Q', 'Jurisdiction__c': 'a024W00000HYAjjQAH', 'Diag_Code__c': 'E042', 'Diag_Code_2nd__c': 'R1310', 'Diag_Code_3rd__c': 'I10', 'Diag_Code_4th__c': 'E785', 'Provider__c': 'ST FRANCIS BARTLETT ', 'Patient__c': 'KELLY LEE  A', 'Patient_ID__c': 'MB02732466', 'Date_of_Birth__c': '06/06/1960', 'Provider_Zip__c': 381334003, 'DRG__c': 'a014W00000ym0WMQAY', 'QPA__c': 'N', 'NPI__c': 1235106154.0, 'POS__c': 11, 'Provider_Specialty__c': 'a008a000015yXODAA2', 'Service_Type__c': 'OUTPATIENT'}
# Processing record 103: {'Claim_ID__c': 'DB647B64671A0EAtksft', 'Provider_TIN__c': 'a0FVF0000020PBl2AM', 'Group_Client__c': 'a0C8a00000r3NZxEAM', 'Claim_Number__c': 'Z24318I1000100', 'Jurisdiction__c': 'a024W00000ICbumQAD', 'Diag_Code__c': 'F1320', 'Diag_Code_2nd__c': 'F13239', 'Diag_Code_3rd__c': 'F1420', 'Diag_Code_4th__c': 'F1423', 'Provider__c': 'LEGACY HEALING CENTER CALIFORNIA ', 'Patient__c': 'RUBINO MARGARET  ', 'Patient_ID__c': '155583644', 'Date_of_Birth__c': '12/15/1962', 'Provider_Zip__c': 900461741, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': nan, 'POS__c': 21, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 104: {'Claim_ID__c': 'C1C2F5EB8A94635tksft', 'Provider_TIN__c': 'a0FVF000001Zaw52AC', 'Group_Client__c': 'a0C8a000017cLiDEAU', 'Claim_Number__c': 'ECI001BVL22421344100', 'Jurisdiction__c': 'a024W00000ICbumQAD', 'Diag_Code__c': 'F1120', 'Diag_Code_2nd__c': nan, 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'WE LEVEL UP CALIFORNIA LLC ', 'Patient__c': 'TOOMBS JARRATT B', 'Patient_ID__c': '223047099', 'Date_of_Birth__c': '03/15/1974', 'Provider_Zip__c': 925304523, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': 1740546209.0, 'POS__c': 11, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 105: {'Claim_ID__c': '306ED06B110EB46tksft', 'Provider_TIN__c': 'a0F4W00000W1KI2UAN', 'Group_Client__c': 'a0CUu00000BrjTqMAJ', 'Claim_Number__c': '243191634Q', 'Jurisdiction__c': 'a024W00000HYAjJQAX', 'Diag_Code__c': 'M5412', 'Diag_Code_2nd__c': 'M5416', 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'SULLIVAN COUNTY COMM HOSPITAL ', 'Patient__c': 'FISCUS WILLIAM  L', 'Patient_ID__c': '589527937', 'Date_of_Birth__c': '10/05/1982', 'Provider_Zip__c': 478827523, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': 1467921833.0, 'POS__c': 13, 'Provider_Specialty__c': 'a008a000015yXOFAA2', 'Service_Type__c': 'OUTPATIENT'}
# Processing record 106: {'Claim_ID__c': '33B4BD584A46C06tksft', 'Provider_TIN__c': 'a0FVF0000020PEz2AM', 'Group_Client__c': 'a0C8a00000r3NaUEAU', 'Claim_Number__c': 'Z24320I1000025', 'Jurisdiction__c': 'a024W00000ICburQAD', 'Diag_Code__c': 'F332', 'Diag_Code_2nd__c': nan, 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'CT CLINICAL SERVICES INC ', 'Patient__c': 'OCONNOR DILELLO KATHLEEN ', 'Patient_ID__c': '148769413', 'Date_of_Birth__c': '04/08/2008', 'Provider_Zip__c': 65102014, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': nan, 'POS__c': 55, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Processing record 107: {'Claim_ID__c': '802EF0AD00A30E7tksft', 'Provider_TIN__c': 'a0FVF0000020Pen2AE', 'Group_Client__c': nan, 'Claim_Number__c': '18A91B0008179EE', 'Jurisdiction__c': 'a024W00000HYAjoQAH', 'Diag_Code__c': 'M2352', 'Diag_Code_2nd__c': nan, 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'SEATTLE CHILDRENS HOSPITAL ', 'Patient__c': 'JOHNSTON HARPER A', 'Patient_ID__c': '880402012', 'Date_of_Birth__c': '09/16/2009', 'Provider_Zip__c': 980043829, 'DRG__c': nan, 'QPA__c': 'N', 'NPI__c': 1316174063.0, 'POS__c': 13, 'Provider_Specialty__c': nan, 'Service_Type__c': nan}
# Error during insert: Malformed request https://relianthealthpartners2020--tctdev.sandbox.my.salesforce.com/services/data/v59.0/sobjects/Claims__c/. Response content: [{'message': 'Required fields are missing: [Group_Client__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['Group_Client__c']}]
# Processing record 108: {'Claim_ID__c': '335B5A8307CC238tksft', 'Provider_TIN__c': 'a0F4W00000W1KR6UAN', 'Group_Client__c': 'a0C8a00000r3Gf3EAE', 'Claim_Number__c': '243190938Q', 'Jurisdiction__c': 'a024W00000HYAjjQAH', 'Diag_Code__c': 'F419', 'Diag_Code_2nd__c': nan, 'Diag_Code_3rd__c': nan, 'Diag_Code_4th__c': nan, 'Provider__c': 'ST FRANCIS BARTLETT ', 'Patient__c': 'BLAYDE KADAJAE  ', 'Patient_ID__c': 'MB02411354', 'Date_of_Birth__c': '05/03/1994', 'Provider_Zip__c': 381334003, 'DRG__c': nan, 'QPA__c': 'Y', 'NPI__c': 1215938287.0, 'POS__c': 13, 'Provider_Specialty__c': 'a008a000015yXODAA2', 'Service_Type__c': 'OUTPATIENT'}
# Total records inserted: 103
# Total errors logged: 6

# %%
lines_map = mappings['Line_Item_Object_Map']
map_lines_table, keys = create_df(lines_map, Source_data, sf, new_ids)
map_lines_table.head()
# Out:
# pulling updated Claims__c table
# pulled data slice!
# Merged Claim ID
# pulling updated HCPCS_CPT_Code__c table
# pulled HCPCS_CPT_Code__c
# Merged HCPCS/CPT Code
#        DOS__c  Rev_Code__c  Billed_Amount__c           RHP_ID__c Mod__c  \
# 0  09/26/2024          320             987.0  a06VF00000AHZLNYA5    NaN
# 1  10/17/2024          510              65.0  a06VF00000AHSIMYA5    NaN
# 2  10/22/2024          278               3.0  a06VF00000AHWCFYA5    NaN
# 3  10/22/2024          300              54.0  a06VF00000AHWCFYA5    NaN
# 4  10/22/2024          310            1000.0  a06VF00000AHWCFYA5     59
#
#   Mod_2nd__c  Units__c   MAR__c   HCPCS_CPT_Code__c  Line_ID__c  \
# 0        NaN         1   156.72  a0b4W00000y1IFrQAM           1
# 1        NaN         1    65.00  a0b4W00000y1JRaQAM           1
# 2        NaN         1     3.00                 NaN           1
# 3        NaN         1    54.00  a0b4W00000y1IqZQAU           2
# 4        NaN         4  1000.00  a0b4W00000y1INfQAM           3
#
#   Exp_Code_2nd__c
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
new_ids, errors = insert_records(map_lines_table.drop_duplicates(), keys, sf) ###insert new line records
# Out:
# Processing record 0: {'DOS__c': '09/26/2024', 'Rev_Code__c': 320, 'Billed_Amount__c': 987.0, 'RHP_ID__c': 'a06VF00000AHZLNYA5', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 156.72, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IFrQAM', 'Line_ID__c': 1, 'Exp_Code_2nd__c': nan}
# Processing record 1: {'DOS__c': '10/17/2024', 'Rev_Code__c': 510, 'Billed_Amount__c': 65.0, 'RHP_ID__c': 'a06VF00000AHSIMYA5', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 65.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1JRaQAM', 'Line_ID__c': 1, 'Exp_Code_2nd__c': nan}
# Processing record 2: {'DOS__c': '10/22/2024', 'Rev_Code__c': 278, 'Billed_Amount__c': 3.0, 'RHP_ID__c': 'a06VF00000AHWCFYA5', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 3.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 1, 'Exp_Code_2nd__c': nan}
# Processing record 3: {'DOS__c': '10/22/2024', 'Rev_Code__c': 300, 'Billed_Amount__c': 54.0, 'RHP_ID__c': 'a06VF00000AHWCFYA5', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 54.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IqZQAU', 'Line_ID__c': 2, 'Exp_Code_2nd__c': nan}
# Processing record 4: {'DOS__c': '10/22/2024', 'Rev_Code__c': 310, 'Billed_Amount__c': 1000.0, 'RHP_ID__c': 'a06VF00000AHWCFYA5', 'Mod__c': '59', 'Mod_2nd__c': nan, 'Units__c': 4, 'MAR__c': 1000.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1INfQAM', 'Line_ID__c': 3, 'Exp_Code_2nd__c': nan}
# Processing record 5: {'DOS__c': '10/22/2024', 'Rev_Code__c': 310, 'Billed_Amount__c': 1159.0, 'RHP_ID__c': 'a06VF00000AHWCFYA5', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 1159.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1INwQAM', 'Line_ID__c': 4, 'Exp_Code_2nd__c': nan}
# Processing record 6: {'DOS__c': '10/22/2024', 'Rev_Code__c': 370, 'Billed_Amount__c': 1227.0, 'RHP_ID__c': 'a06VF00000AHWCFYA5', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 3, 'MAR__c': 1227.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 5, 'Exp_Code_2nd__c': nan}
# Processing record 7: {'DOS__c': '10/22/2024', 'Rev_Code__c': 636, 'Billed_Amount__c': 155.0, 'RHP_ID__c': 'a06VF00000AHWCFYA5', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 70, 'MAR__c': 155.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1JZ9QAM', 'Line_ID__c': 6, 'Exp_Code_2nd__c': nan}
# Processing record 8: {'DOS__c': '10/22/2024', 'Rev_Code__c': 710, 'Billed_Amount__c': 48.0, 'RHP_ID__c': 'a06VF00000AHWCFYA5', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 3, 'MAR__c': 48.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 7, 'Exp_Code_2nd__c': nan}
# Processing record 9: {'DOS__c': '10/22/2024', 'Rev_Code__c': 750, 'Billed_Amount__c': 3326.0, 'RHP_ID__c': 'a06VF00000AHWCFYA5', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 3326.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1HcPQAU', 'Line_ID__c': 8, 'Exp_Code_2nd__c': nan}
# Processing record 10: {'DOS__c': '10/22/2024', 'Rev_Code__c': 750, 'Billed_Amount__c': 3326.0, 'RHP_ID__c': 'a06VF00000AHWCFYA5', 'Mod__c': 'PT', 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 3326.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1HhRQAU', 'Line_ID__c': 9, 'Exp_Code_2nd__c': nan}
# Processing record 11: {'DOS__c': '03/13/2024', 'Rev_Code__c': 490, 'Billed_Amount__c': 55585.0, 'RHP_ID__c': 'a06VF00000AHY9CYAX', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 55585.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1GwWQAU', 'Line_ID__c': 1, 'Exp_Code_2nd__c': 'C000'}
# Processing record 12: {'DOS__c': '03/13/2024', 'Rev_Code__c': 490, 'Billed_Amount__c': 18332.0, 'RHP_ID__c': 'a06VF00000AHY9CYAX', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 18332.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1Gx7QAE', 'Line_ID__c': 2, 'Exp_Code_2nd__c': 'C000'}
# Processing record 13: {'DOS__c': '03/13/2024', 'Rev_Code__c': 490, 'Billed_Amount__c': 18332.0, 'RHP_ID__c': 'a06VF00000AHY9CYAX', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 0.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1Gx7QAE', 'Line_ID__c': 3, 'Exp_Code_2nd__c': 'C18'}
# Processing record 14: {'DOS__c': '03/13/2024', 'Rev_Code__c': 490, 'Billed_Amount__c': 9647.0, 'RHP_ID__c': 'a06VF00000AHY9CYAX', 'Mod__c': '59', 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 9647.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1Gx0QAE', 'Line_ID__c': 4, 'Exp_Code_2nd__c': 'C000'}
# Processing record 15: {'DOS__c': '03/13/2024', 'Rev_Code__c': 490, 'Billed_Amount__c': 7585.0, 'RHP_ID__c': 'a06VF00000AHY9CYAX', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 0.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IhHQAU', 'Line_ID__c': 5, 'Exp_Code_2nd__c': 'C286'}
# Processing record 16: {'DOS__c': '03/13/2024', 'Rev_Code__c': 490, 'Billed_Amount__c': 7585.0, 'RHP_ID__c': 'a06VF00000AHY9CYAX', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 0.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IhIQAU', 'Line_ID__c': 6, 'Exp_Code_2nd__c': 'C286'}
# Processing record 17: {'DOS__c': '03/13/2024', 'Rev_Code__c': 490, 'Billed_Amount__c': 37878.0, 'RHP_ID__c': 'a06VF00000AHY9CYAX', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 37878.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1GwXQAU', 'Line_ID__c': 7, 'Exp_Code_2nd__c': 'C000'}
# Processing record 18: {'DOS__c': '03/13/2024', 'Rev_Code__c': 278, 'Billed_Amount__c': 426.83, 'RHP_ID__c': 'a06VF00000AHY9CYAX', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 426.83, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 8, 'Exp_Code_2nd__c': 'C000'}
# Processing record 19: {'DOS__c': '03/13/2024', 'Rev_Code__c': 279, 'Billed_Amount__c': 971.82, 'RHP_ID__c': 'a06VF00000AHY9CYAX', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 3, 'MAR__c': 0.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 9, 'Exp_Code_2nd__c': 'C286'}
# Processing record 20: {'DOS__c': '03/13/2024', 'Rev_Code__c': 278, 'Billed_Amount__c': 3841.47, 'RHP_ID__c': 'a06VF00000AHY9CYAX', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 10, 'MAR__c': 3841.47, 'HCPCS_CPT_Code__c': 'a0bVF000000SeddYAC', 'Line_ID__c': 10, 'Exp_Code_2nd__c': 'C000'}
# Processing record 21: {'DOS__c': '10/11/2024', 'Rev_Code__c': 480, 'Billed_Amount__c': 9000.0, 'RHP_ID__c': 'a06VF00000AHVbBYAX', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 9000.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1ISkQAM', 'Line_ID__c': 1, 'Exp_Code_2nd__c': nan}
# Processing record 22: {'DOS__c': '09/13/2024', 'Rev_Code__c': 450, 'Billed_Amount__c': 2520.0, 'RHP_ID__c': 'a06VF00000AHZMzYAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 531.84, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IaRQAU', 'Line_ID__c': 1, 'Exp_Code_2nd__c': nan}
# Processing record 23: {'DOS__c': '10/09/2024', 'Rev_Code__c': 300, 'Billed_Amount__c': 24.6, 'RHP_ID__c': 'a06VF00000AHRKdYAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 20.91, 'HCPCS_CPT_Code__c': 'a0b4W00000y1Ij6QAE', 'Line_ID__c': 1, 'Exp_Code_2nd__c': nan}
# Processing record 24: {'DOS__c': '10/09/2024', 'Rev_Code__c': 320, 'Billed_Amount__c': 417.69, 'RHP_ID__c': 'a06VF00000AHRKdYAP', 'Mod__c': 'TC', 'Mod_2nd__c': 'LT', 'Units__c': 1, 'MAR__c': 355.04, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IFGQA2', 'Line_ID__c': 2, 'Exp_Code_2nd__c': nan}
# Processing record 25: {'DOS__c': '10/09/2024', 'Rev_Code__c': 301, 'Billed_Amount__c': 76.2, 'RHP_ID__c': 'a06VF00000AHRKdYAP', 'Mod__c': 'TC', 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 64.77, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IoNQAU', 'Line_ID__c': 3, 'Exp_Code_2nd__c': nan}
# Processing record 26: {'DOS__c': '10/09/2024', 'Rev_Code__c': 300, 'Billed_Amount__c': 64.88, 'RHP_ID__c': 'a06VF00000AHRKdYAP', 'Mod__c': 'TC', 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 55.15, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IyzQAE', 'Line_ID__c': 4, 'Exp_Code_2nd__c': nan}
# Processing record 27: {'DOS__c': '10/09/2024', 'Rev_Code__c': 450, 'Billed_Amount__c': 1178.82, 'RHP_ID__c': 'a06VF00000AHRKdYAP', 'Mod__c': '25', 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 1002.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IaRQAU', 'Line_ID__c': 5, 'Exp_Code_2nd__c': nan}
# Processing record 28: {'DOS__c': '10/09/2024', 'Rev_Code__c': 260, 'Billed_Amount__c': 324.63, 'RHP_ID__c': 'a06VF00000AHRKdYAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 275.94, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IXzQAM', 'Line_ID__c': 6, 'Exp_Code_2nd__c': nan}
# Processing record 29: {'DOS__c': '10/09/2024', 'Rev_Code__c': 260, 'Billed_Amount__c': 298.95, 'RHP_ID__c': 'a06VF00000AHRKdYAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 254.11, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IY9QAM', 'Line_ID__c': 7, 'Exp_Code_2nd__c': nan}
# Processing record 30: {'DOS__c': '10/09/2024', 'Rev_Code__c': 636, 'Billed_Amount__c': 24.19, 'RHP_ID__c': 'a06VF00000AHRKdYAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 2, 'MAR__c': 20.56, 'HCPCS_CPT_Code__c': 'a0b4W00000y1JY1QAM', 'Line_ID__c': 8, 'Exp_Code_2nd__c': nan}
# Processing record 31: {'DOS__c': '10/09/2024', 'Rev_Code__c': 250, 'Billed_Amount__c': 48.47, 'RHP_ID__c': 'a06VF00000AHRKdYAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 41.2, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 9, 'Exp_Code_2nd__c': nan}
# Processing record 32: {'DOS__c': '11/08/2024', 'Rev_Code__c': 320, 'Billed_Amount__c': 373.0, 'RHP_ID__c': 'a06VF00000AHVbCYAX', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 373.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IGEQA2', 'Line_ID__c': 1, 'Exp_Code_2nd__c': nan}
# Processing record 33: {'DOS__c': '11/08/2024', 'Rev_Code__c': 402, 'Billed_Amount__c': 716.0, 'RHP_ID__c': 'a06VF00000AHVbCYAX', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 716.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IJ3QAM', 'Line_ID__c': 2, 'Exp_Code_2nd__c': nan}
# Processing record 34: {'DOS__c': '10/16/2024', 'Rev_Code__c': 550, 'Billed_Amount__c': 295.24, 'RHP_ID__c': 'a06VF00000AHZObYAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 100.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1JlbQAE', 'Line_ID__c': 1, 'Exp_Code_2nd__c': nan}
# Processing record 35: {'DOS__c': '10/31/2024', 'Rev_Code__c': 914, 'Billed_Amount__c': 2000.0, 'RHP_ID__c': 'a06VF00000AHZQDYA5', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 2000.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IOfQAM', 'Line_ID__c': 1, 'Exp_Code_2nd__c': 'C000'}
# Processing record 36: {'DOS__c': '11/04/2024', 'Rev_Code__c': 360, 'Billed_Amount__c': 9199.0, 'RHP_ID__c': 'a06VF00000AHSNKYA5', 'Mod__c': '33', 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 9199.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1HhNQAU', 'Line_ID__c': 1, 'Exp_Code_2nd__c': nan}
# Processing record 37: {'DOS__c': '11/04/2024', 'Rev_Code__c': 312, 'Billed_Amount__c': 1936.0, 'RHP_ID__c': 'a06VF00000AHSNKYA5', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 8, 'MAR__c': 1936.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1INfQAM', 'Line_ID__c': 2, 'Exp_Code_2nd__c': nan}
# Processing record 38: {'DOS__c': '10/30/2024', 'Rev_Code__c': 510, 'Billed_Amount__c': 135.0, 'RHP_ID__c': 'a06VF00000AHZRpYAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 135.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1JBEQA2', 'Line_ID__c': 1, 'Exp_Code_2nd__c': 'C000'}
# Processing record 39: {'DOS__c': '09/03/2024', 'Rev_Code__c': 360, 'Billed_Amount__c': 10117.13, 'RHP_ID__c': 'a06VF00000AHYqkYAH', 'Mod__c': 'RT', 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 7587.85, 'HCPCS_CPT_Code__c': 'a0b4W00000y1H2uQAE', 'Line_ID__c': 1, 'Exp_Code_2nd__c': nan}
# Processing record 40: {'DOS__c': '09/03/2024', 'Rev_Code__c': 636, 'Billed_Amount__c': 50.84, 'RHP_ID__c': 'a06VF00000AHYqkYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 10, 'MAR__c': 38.13, 'HCPCS_CPT_Code__c': 'a0b4W00000y1Ja9QAE', 'Line_ID__c': 2, 'Exp_Code_2nd__c': nan}
# Processing record 41: {'DOS__c': '09/03/2024', 'Rev_Code__c': 636, 'Billed_Amount__c': 45.24, 'RHP_ID__c': 'a06VF00000AHYqkYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 4, 'MAR__c': 33.93, 'HCPCS_CPT_Code__c': 'a0b4W00000y1JWPQA2', 'Line_ID__c': 3, 'Exp_Code_2nd__c': nan}
# Processing record 42: {'DOS__c': '09/03/2024', 'Rev_Code__c': 636, 'Billed_Amount__c': 33.23, 'RHP_ID__c': 'a06VF00000AHYqkYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 10, 'MAR__c': 24.92, 'HCPCS_CPT_Code__c': 'a0b4W00000y1JX9QAM', 'Line_ID__c': 4, 'Exp_Code_2nd__c': nan}
# Processing record 43: {'DOS__c': '09/03/2024', 'Rev_Code__c': 636, 'Billed_Amount__c': 28.88, 'RHP_ID__c': 'a06VF00000AHYqkYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 15, 'MAR__c': 21.66, 'HCPCS_CPT_Code__c': 'a0b4W00000y1JZ9QAM', 'Line_ID__c': 5, 'Exp_Code_2nd__c': nan}
# Processing record 44: {'DOS__c': '09/03/2024', 'Rev_Code__c': 636, 'Billed_Amount__c': 26.54, 'RHP_ID__c': 'a06VF00000AHYqkYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 100, 'MAR__c': 19.91, 'HCPCS_CPT_Code__c': 'a0bVF000000Sec1YAC', 'Line_ID__c': 6, 'Exp_Code_2nd__c': nan}
# Processing record 45: {'DOS__c': '09/03/2024', 'Rev_Code__c': 636, 'Billed_Amount__c': 25.74, 'RHP_ID__c': 'a06VF00000AHYqkYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 2, 'MAR__c': 19.31, 'HCPCS_CPT_Code__c': 'a0b4W00000y1JYRQA2', 'Line_ID__c': 7, 'Exp_Code_2nd__c': nan}
# Processing record 46: {'DOS__c': '09/03/2024', 'Rev_Code__c': 636, 'Billed_Amount__c': 22.8, 'RHP_ID__c': 'a06VF00000AHYqkYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 4, 'MAR__c': 17.1, 'HCPCS_CPT_Code__c': 'a0b4W00000y1JYkQAM', 'Line_ID__c': 8, 'Exp_Code_2nd__c': nan}
# Processing record 47: {'DOS__c': '09/03/2024', 'Rev_Code__c': 636, 'Billed_Amount__c': 22.07, 'RHP_ID__c': 'a06VF00000AHYqkYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 16.55, 'HCPCS_CPT_Code__c': 'a0b4W00000y1JZdQAM', 'Line_ID__c': 9, 'Exp_Code_2nd__c': nan}
# Processing record 48: {'DOS__c': '09/03/2024', 'Rev_Code__c': 636, 'Billed_Amount__c': 26.87, 'RHP_ID__c': 'a06VF00000AHYqkYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 2, 'MAR__c': 20.15, 'HCPCS_CPT_Code__c': 'a0b4W00000y1JY1QAM', 'Line_ID__c': 10, 'Exp_Code_2nd__c': nan}
# Processing record 49: {'DOS__c': '09/03/2024', 'Rev_Code__c': 710, 'Billed_Amount__c': 1979.52, 'RHP_ID__c': 'a06VF00000AHYqkYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 1484.64, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 11, 'Exp_Code_2nd__c': nan}
# Processing record 50: {'DOS__c': '09/03/2024', 'Rev_Code__c': 270, 'Billed_Amount__c': 674.07, 'RHP_ID__c': 'a06VF00000AHYqkYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 505.55, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 12, 'Exp_Code_2nd__c': nan}
# Processing record 51: {'DOS__c': '09/03/2024', 'Rev_Code__c': 250, 'Billed_Amount__c': 51.24, 'RHP_ID__c': 'a06VF00000AHYqkYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 38.43, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 13, 'Exp_Code_2nd__c': nan}
# Processing record 52: {'DOS__c': '09/03/2024', 'Rev_Code__c': 250, 'Billed_Amount__c': 22.24, 'RHP_ID__c': 'a06VF00000AHYqkYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 16.68, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 14, 'Exp_Code_2nd__c': nan}
# Processing record 53: {'DOS__c': '09/03/2024', 'Rev_Code__c': 370, 'Billed_Amount__c': 789.75, 'RHP_ID__c': 'a06VF00000AHYqkYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 75, 'MAR__c': 592.31, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 15, 'Exp_Code_2nd__c': nan}
# Processing record 54: {'DOS__c': '09/03/2024', 'Rev_Code__c': 278, 'Billed_Amount__c': 0.0, 'RHP_ID__c': 'a06VF00000AHYqkYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 9, 'MAR__c': 0.0, 'HCPCS_CPT_Code__c': 'a0bVF000000SeddYAC', 'Line_ID__c': 16, 'Exp_Code_2nd__c': nan}
# Processing record 55: {'DOS__c': '11/06/2024', 'Rev_Code__c': 912, 'Billed_Amount__c': 2970.0, 'RHP_ID__c': 'a06VF00000AHR69YAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 0.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1JV4QAM', 'Line_ID__c': 1, 'Exp_Code_2nd__c': 'C286'}
# Processing record 56: {'DOS__c': '11/07/2024', 'Rev_Code__c': 912, 'Billed_Amount__c': 2970.0, 'RHP_ID__c': 'a06VF00000AHR69YAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 0.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1JV4QAM', 'Line_ID__c': 2, 'Exp_Code_2nd__c': 'C286'}
# Processing record 57: {'DOS__c': '11/08/2024', 'Rev_Code__c': 912, 'Billed_Amount__c': 2970.0, 'RHP_ID__c': 'a06VF00000AHR69YAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 0.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1JV4QAM', 'Line_ID__c': 3, 'Exp_Code_2nd__c': 'C286'}
# Processing record 58: {'DOS__c': '11/09/2024', 'Rev_Code__c': 912, 'Billed_Amount__c': 2970.0, 'RHP_ID__c': 'a06VF00000AHR69YAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 0.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1JV4QAM', 'Line_ID__c': 4, 'Exp_Code_2nd__c': 'C286'}
# Processing record 59: {'DOS__c': '11/10/2024', 'Rev_Code__c': 912, 'Billed_Amount__c': 2970.0, 'RHP_ID__c': 'a06VF00000AHR69YAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 0.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1JV4QAM', 'Line_ID__c': 5, 'Exp_Code_2nd__c': 'C286'}
# Processing record 60: {'DOS__c': '11/05/2024', 'Rev_Code__c': 912, 'Billed_Amount__c': 2970.0, 'RHP_ID__c': 'a06VF00000AHR69YAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 0.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1JV4QAM', 'Line_ID__c': 6, 'Exp_Code_2nd__c': 'C286'}
# Processing record 61: {'DOS__c': '10/23/2024', 'Rev_Code__c': 513, 'Billed_Amount__c': 450.0, 'RHP_ID__c': 'a06VF00000AHXHyYAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 450.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1Ia4QAE', 'Line_ID__c': 1, 'Exp_Code_2nd__c': 'C000'}
# Processing record 62: {'DOS__c': '09/16/2024', 'Rev_Code__c': 905, 'Billed_Amount__c': 1000.0, 'RHP_ID__c': 'a06VF00000AHZTRYA5', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 0.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1JlOQAU', 'Line_ID__c': 1, 'Exp_Code_2nd__c': 'C286'}
# Processing record 63: {'DOS__c': '09/17/2024', 'Rev_Code__c': 905, 'Billed_Amount__c': 1000.0, 'RHP_ID__c': 'a06VF00000AHZTRYA5', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 0.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1JlOQAU', 'Line_ID__c': 2, 'Exp_Code_2nd__c': 'C286'}
# Processing record 64: {'DOS__c': '09/18/2024', 'Rev_Code__c': 905, 'Billed_Amount__c': 1000.0, 'RHP_ID__c': 'a06VF00000AHZTRYA5', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 0.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1JlOQAU', 'Line_ID__c': 3, 'Exp_Code_2nd__c': 'C286'}
# Processing record 65: {'DOS__c': '09/19/2024', 'Rev_Code__c': 905, 'Billed_Amount__c': 1000.0, 'RHP_ID__c': 'a06VF00000AHZTRYA5', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 0.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1JlOQAU', 'Line_ID__c': 4, 'Exp_Code_2nd__c': 'C286'}
# Processing record 66: {'DOS__c': '10/15/2024', 'Rev_Code__c': 420, 'Billed_Amount__c': 199.0, 'RHP_ID__c': 'a06VF00000AHZV3YAP', 'Mod__c': 'GP', 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 199.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IYqQAM', 'Line_ID__c': 1, 'Exp_Code_2nd__c': nan}
# Processing record 67: {'DOS__c': '10/11/2024', 'Rev_Code__c': 420, 'Billed_Amount__c': 398.0, 'RHP_ID__c': 'a06VF00000AHZV3YAP', 'Mod__c': 'GP', 'Mod_2nd__c': nan, 'Units__c': 2, 'MAR__c': 398.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IZ2QAM', 'Line_ID__c': 2, 'Exp_Code_2nd__c': nan}
# Processing record 68: {'DOS__c': '10/15/2024', 'Rev_Code__c': 420, 'Billed_Amount__c': 398.0, 'RHP_ID__c': 'a06VF00000AHZV3YAP', 'Mod__c': 'GP', 'Mod_2nd__c': nan, 'Units__c': 2, 'MAR__c': 398.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IZ2QAM', 'Line_ID__c': 3, 'Exp_Code_2nd__c': nan}
# Processing record 69: {'DOS__c': '10/18/2024', 'Rev_Code__c': 420, 'Billed_Amount__c': 398.0, 'RHP_ID__c': 'a06VF00000AHZV3YAP', 'Mod__c': 'GP', 'Mod_2nd__c': nan, 'Units__c': 2, 'MAR__c': 398.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IZ2QAM', 'Line_ID__c': 4, 'Exp_Code_2nd__c': nan}
# Processing record 70: {'DOS__c': '10/11/2024', 'Rev_Code__c': 420, 'Billed_Amount__c': 404.0, 'RHP_ID__c': 'a06VF00000AHZV3YAP', 'Mod__c': 'GP', 'Mod_2nd__c': nan, 'Units__c': 2, 'MAR__c': 404.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IZJQA2', 'Line_ID__c': 5, 'Exp_Code_2nd__c': nan}
# Processing record 71: {'DOS__c': '10/15/2024', 'Rev_Code__c': 420, 'Billed_Amount__c': 404.0, 'RHP_ID__c': 'a06VF00000AHZV3YAP', 'Mod__c': 'GP', 'Mod_2nd__c': nan, 'Units__c': 2, 'MAR__c': 404.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IZJQA2', 'Line_ID__c': 6, 'Exp_Code_2nd__c': nan}
# Processing record 72: {'DOS__c': '10/18/2024', 'Rev_Code__c': 420, 'Billed_Amount__c': 404.0, 'RHP_ID__c': 'a06VF00000AHZV3YAP', 'Mod__c': 'GP', 'Mod_2nd__c': nan, 'Units__c': 2, 'MAR__c': 404.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IZJQA2', 'Line_ID__c': 7, 'Exp_Code_2nd__c': nan}
# Processing record 73: {'DOS__c': '10/11/2024', 'Rev_Code__c': 420, 'Billed_Amount__c': 207.0, 'RHP_ID__c': 'a06VF00000AHZV3YAP', 'Mod__c': 'GP', 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 207.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1GiTQAU', 'Line_ID__c': 8, 'Exp_Code_2nd__c': nan}
# Processing record 74: {'DOS__c': '11/07/2024', 'Rev_Code__c': 126, 'Billed_Amount__c': 7705.0, 'RHP_ID__c': 'a06VF00000AHZWfYAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 7705.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 1, 'Exp_Code_2nd__c': 'C000'}
# Processing record 75: {'DOS__c': '11/08/2024', 'Rev_Code__c': 402, 'Billed_Amount__c': 247.0, 'RHP_ID__c': 'a06VF00000AHZYHYA5', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 247.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IJ3QAM', 'Line_ID__c': 1, 'Exp_Code_2nd__c': nan}
# Processing record 76: {'DOS__c': '11/05/2024', 'Rev_Code__c': 403, 'Billed_Amount__c': 197.0, 'RHP_ID__c': 'a06VF00000AHZZtYAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 197.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IJjQAM', 'Line_ID__c': 1, 'Exp_Code_2nd__c': nan}
# Processing record 77: {'DOS__c': '11/05/2024', 'Rev_Code__c': 403, 'Billed_Amount__c': 804.0, 'RHP_ID__c': 'a06VF00000AHZZtYAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 804.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IJmQAM', 'Line_ID__c': 2, 'Exp_Code_2nd__c': nan}
# Processing record 78: {'DOS__c': '10/23/2024', 'Rev_Code__c': 513, 'Billed_Amount__c': 450.0, 'RHP_ID__c': 'a06VF00000AHSdQYAX', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 450.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1Ia4QAE', 'Line_ID__c': 1, 'Exp_Code_2nd__c': 'C000'}
# Processing record 79: {'DOS__c': '11/02/2024', 'Rev_Code__c': 481, 'Billed_Amount__c': 18028.0, 'RHP_ID__c': 'a06VF00000AHYvaYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 18028.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 1, 'Exp_Code_2nd__c': 'C000'}
# Processing record 80: {'DOS__c': '11/02/2024', 'Rev_Code__c': 636, 'Billed_Amount__c': 470.09, 'RHP_ID__c': 'a06VF00000AHYvaYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 443, 'MAR__c': 470.09, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 2, 'Exp_Code_2nd__c': 'C000'}
# Processing record 81: {'DOS__c': '11/02/2024', 'Rev_Code__c': 730, 'Billed_Amount__c': 1077.0, 'RHP_ID__c': 'a06VF00000AHYvaYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 3, 'MAR__c': 1077.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 3, 'Exp_Code_2nd__c': 'C000'}
# Processing record 82: {'DOS__c': '11/02/2024', 'Rev_Code__c': 921, 'Billed_Amount__c': 2682.0, 'RHP_ID__c': 'a06VF00000AHYvaYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 2682.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 4, 'Exp_Code_2nd__c': 'C000'}
# Processing record 83: {'DOS__c': '11/02/2024', 'Rev_Code__c': 202, 'Billed_Amount__c': 15620.0, 'RHP_ID__c': 'a06VF00000AHYvaYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 15620.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 5, 'Exp_Code_2nd__c': 'C000'}
# Processing record 84: {'DOS__c': '11/02/2024', 'Rev_Code__c': 350, 'Billed_Amount__c': 8390.0, 'RHP_ID__c': 'a06VF00000AHYvaYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 2, 'MAR__c': 8390.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 6, 'Exp_Code_2nd__c': 'C000'}
# Processing record 85: {'DOS__c': '11/02/2024', 'Rev_Code__c': 352, 'Billed_Amount__c': 3051.0, 'RHP_ID__c': 'a06VF00000AHYvaYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 3051.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 7, 'Exp_Code_2nd__c': 'C000'}
# Processing record 86: {'DOS__c': '11/02/2024', 'Rev_Code__c': 361, 'Billed_Amount__c': 633.0, 'RHP_ID__c': 'a06VF00000AHYvaYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 633.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 8, 'Exp_Code_2nd__c': 'C000'}
# Processing record 87: {'DOS__c': '11/02/2024', 'Rev_Code__c': 370, 'Billed_Amount__c': 231.0, 'RHP_ID__c': 'a06VF00000AHYvaYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 2, 'MAR__c': 231.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 9, 'Exp_Code_2nd__c': 'C000'}
# Processing record 88: {'DOS__c': '11/02/2024', 'Rev_Code__c': 402, 'Billed_Amount__c': 1144.0, 'RHP_ID__c': 'a06VF00000AHYvaYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 1144.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 10, 'Exp_Code_2nd__c': 'C000'}
# Processing record 89: {'DOS__c': '11/02/2024', 'Rev_Code__c': 410, 'Billed_Amount__c': 523.0, 'RHP_ID__c': 'a06VF00000AHYvaYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 523.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 11, 'Exp_Code_2nd__c': 'C000'}
# Processing record 90: {'DOS__c': '11/02/2024', 'Rev_Code__c': 450, 'Billed_Amount__c': 5390.0, 'RHP_ID__c': 'a06VF00000AHYvaYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 5390.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 12, 'Exp_Code_2nd__c': 'C000'}
# Processing record 91: {'DOS__c': '11/02/2024', 'Rev_Code__c': 460, 'Billed_Amount__c': 138.0, 'RHP_ID__c': 'a06VF00000AHYvaYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 138.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 13, 'Exp_Code_2nd__c': 'C000'}
# Processing record 92: {'DOS__c': '11/02/2024', 'Rev_Code__c': 250, 'Billed_Amount__c': 467.49, 'RHP_ID__c': 'a06VF00000AHYvaYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 770, 'MAR__c': 467.49, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 14, 'Exp_Code_2nd__c': 'C000'}
# Processing record 93: {'DOS__c': '11/02/2024', 'Rev_Code__c': 255, 'Billed_Amount__c': 196.8, 'RHP_ID__c': 'a06VF00000AHYvaYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 75, 'MAR__c': 196.8, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 15, 'Exp_Code_2nd__c': 'C000'}
# Processing record 94: {'DOS__c': '11/02/2024', 'Rev_Code__c': 258, 'Billed_Amount__c': 165.6, 'RHP_ID__c': 'a06VF00000AHYvaYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 5, 'MAR__c': 165.6, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 16, 'Exp_Code_2nd__c': 'C000'}
# Processing record 95: {'DOS__c': '11/02/2024', 'Rev_Code__c': 270, 'Billed_Amount__c': 221.66, 'RHP_ID__c': 'a06VF00000AHYvaYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 3, 'MAR__c': 221.66, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 17, 'Exp_Code_2nd__c': 'C000'}
# Processing record 96: {'DOS__c': '11/02/2024', 'Rev_Code__c': 272, 'Billed_Amount__c': 429.19, 'RHP_ID__c': 'a06VF00000AHYvaYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 9, 'MAR__c': 429.19, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 18, 'Exp_Code_2nd__c': 'C000'}
# Processing record 97: {'DOS__c': '11/02/2024', 'Rev_Code__c': 278, 'Billed_Amount__c': 489.18, 'RHP_ID__c': 'a06VF00000AHYvaYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 7, 'MAR__c': 489.18, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 19, 'Exp_Code_2nd__c': 'C000'}
# Processing record 98: {'DOS__c': '11/02/2024', 'Rev_Code__c': 300, 'Billed_Amount__c': 1591.0, 'RHP_ID__c': 'a06VF00000AHYvaYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 8, 'MAR__c': 1591.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 20, 'Exp_Code_2nd__c': 'C000'}
# Processing record 99: {'DOS__c': '11/02/2024', 'Rev_Code__c': 301, 'Billed_Amount__c': 2415.0, 'RHP_ID__c': 'a06VF00000AHYvaYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 14, 'MAR__c': 2415.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 21, 'Exp_Code_2nd__c': 'C000'}
# Processing record 100: {'DOS__c': '11/02/2024', 'Rev_Code__c': 305, 'Billed_Amount__c': 527.0, 'RHP_ID__c': 'a06VF00000AHYvaYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 4, 'MAR__c': 527.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 22, 'Exp_Code_2nd__c': 'C000'}
# Processing record 101: {'DOS__c': '11/02/2024', 'Rev_Code__c': 307, 'Billed_Amount__c': 107.0, 'RHP_ID__c': 'a06VF00000AHYvaYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 107.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 23, 'Exp_Code_2nd__c': 'C000'}
# Processing record 102: {'DOS__c': '11/02/2024', 'Rev_Code__c': 320, 'Billed_Amount__c': 473.0, 'RHP_ID__c': 'a06VF00000AHYvaYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 473.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 24, 'Exp_Code_2nd__c': 'C000'}
# Processing record 103: {'DOS__c': '11/02/2024', 'Rev_Code__c': 324, 'Billed_Amount__c': 429.0, 'RHP_ID__c': 'a06VF00000AHYvaYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 429.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 25, 'Exp_Code_2nd__c': 'C000'}
# Processing record 104: {'DOS__c': '11/08/2024', 'Rev_Code__c': 250, 'Billed_Amount__c': 46.0, 'RHP_ID__c': 'a06VF00000AHZbVYAX', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 46.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 1, 'Exp_Code_2nd__c': nan}
# Processing record 105: {'DOS__c': '11/08/2024', 'Rev_Code__c': 450, 'Billed_Amount__c': 2348.0, 'RHP_ID__c': 'a06VF00000AHZbVYAX', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 2348.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IaRQAU', 'Line_ID__c': 2, 'Exp_Code_2nd__c': nan}
# Processing record 106: {'DOS__c': '09/22/2024', 'Rev_Code__c': 1001, 'Billed_Amount__c': 3800.0, 'RHP_ID__c': 'a06VF00000AHZbWYAX', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 3800.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 1, 'Exp_Code_2nd__c': 'C000'}
# Processing record 107: {'DOS__c': '11/08/2024', 'Rev_Code__c': 258, 'Billed_Amount__c': 138.0, 'RHP_ID__c': 'a06VF00000AHYZ0YAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 138.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1JahQAE', 'Line_ID__c': 1, 'Exp_Code_2nd__c': nan}
# Processing record 108: {'DOS__c': '11/08/2024', 'Rev_Code__c': 300, 'Billed_Amount__c': 38.0, 'RHP_ID__c': 'a06VF00000AHYZ0YAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 38.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1Ij6QAE', 'Line_ID__c': 2, 'Exp_Code_2nd__c': nan}
# Processing record 109: {'DOS__c': '11/08/2024', 'Rev_Code__c': 300, 'Billed_Amount__c': 865.0, 'RHP_ID__c': 'a06VF00000AHYZ0YAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 865.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IoNQAU', 'Line_ID__c': 3, 'Exp_Code_2nd__c': nan}
# Processing record 110: {'DOS__c': '11/08/2024', 'Rev_Code__c': 300, 'Billed_Amount__c': 191.0, 'RHP_ID__c': 'a06VF00000AHYZ0YAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 191.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IqSQAU', 'Line_ID__c': 4, 'Exp_Code_2nd__c': nan}
# Processing record 111: {'DOS__c': '11/08/2024', 'Rev_Code__c': 300, 'Billed_Amount__c': 171.0, 'RHP_ID__c': 'a06VF00000AHYZ0YAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 171.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IyzQAE', 'Line_ID__c': 5, 'Exp_Code_2nd__c': nan}
# Processing record 112: {'DOS__c': '11/08/2024', 'Rev_Code__c': 352, 'Billed_Amount__c': 6124.0, 'RHP_ID__c': 'a06VF00000AHYZ0YAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 6124.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IGNQA2', 'Line_ID__c': 6, 'Exp_Code_2nd__c': nan}
# Processing record 113: {'DOS__c': '11/08/2024', 'Rev_Code__c': 450, 'Billed_Amount__c': 368.0, 'RHP_ID__c': 'a06VF00000AHYZ0YAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 368.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IY9QAM', 'Line_ID__c': 7, 'Exp_Code_2nd__c': nan}
# Processing record 114: {'DOS__c': '11/08/2024', 'Rev_Code__c': 450, 'Billed_Amount__c': 4703.0, 'RHP_ID__c': 'a06VF00000AHYZ0YAP', 'Mod__c': '25', 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 4703.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IaTQAU', 'Line_ID__c': 8, 'Exp_Code_2nd__c': nan}
# Processing record 115: {'DOS__c': '11/08/2024', 'Rev_Code__c': 636, 'Billed_Amount__c': 4.65, 'RHP_ID__c': 'a06VF00000AHYZ0YAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 4.65, 'HCPCS_CPT_Code__c': 'a0b4W00000y1JY1QAM', 'Line_ID__c': 9, 'Exp_Code_2nd__c': nan}
# Processing record 116: {'DOS__c': '11/08/2024', 'Rev_Code__c': 300, 'Billed_Amount__c': 19.0, 'RHP_ID__c': nan, 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 19.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1Ij6QAE', 'Line_ID__c': 1, 'Exp_Code_2nd__c': nan}
# Error during insert: Malformed request https://relianthealthpartners2020--tctdev.sandbox.my.salesforce.com/services/data/v59.0/sobjects/Line_Items__c/. Response content: [{'message': 'Required fields are missing: [RHP_ID__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['RHP_ID__c']}]
# Processing record 117: {'DOS__c': '11/08/2024', 'Rev_Code__c': 301, 'Billed_Amount__c': 565.0, 'RHP_ID__c': nan, 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 565.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IoNQAU', 'Line_ID__c': 2, 'Exp_Code_2nd__c': nan}
# Error during insert: Malformed request https://relianthealthpartners2020--tctdev.sandbox.my.salesforce.com/services/data/v59.0/sobjects/Line_Items__c/. Response content: [{'message': 'Required fields are missing: [RHP_ID__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['RHP_ID__c']}]
# Processing record 118: {'DOS__c': '11/08/2024', 'Rev_Code__c': 301, 'Billed_Amount__c': 279.0, 'RHP_ID__c': nan, 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 279.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1ItmQAE', 'Line_ID__c': 3, 'Exp_Code_2nd__c': nan}
# Error during insert: Malformed request https://relianthealthpartners2020--tctdev.sandbox.my.salesforce.com/services/data/v59.0/sobjects/Line_Items__c/. Response content: [{'message': 'Required fields are missing: [RHP_ID__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['RHP_ID__c']}]
# Processing record 119: {'DOS__c': '11/08/2024', 'Rev_Code__c': 301, 'Billed_Amount__c': 308.0, 'RHP_ID__c': nan, 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 308.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IuNQAU', 'Line_ID__c': 4, 'Exp_Code_2nd__c': nan}
# Error during insert: Malformed request https://relianthealthpartners2020--tctdev.sandbox.my.salesforce.com/services/data/v59.0/sobjects/Line_Items__c/. Response content: [{'message': 'Required fields are missing: [RHP_ID__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['RHP_ID__c']}]
# Processing record 120: {'DOS__c': '11/08/2024', 'Rev_Code__c': 301, 'Billed_Amount__c': 154.0, 'RHP_ID__c': nan, 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 154.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IusQAE', 'Line_ID__c': 5, 'Exp_Code_2nd__c': nan}
# Error during insert: Malformed request https://relianthealthpartners2020--tctdev.sandbox.my.salesforce.com/services/data/v59.0/sobjects/Line_Items__c/. Response content: [{'message': 'Required fields are missing: [RHP_ID__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['RHP_ID__c']}]
# Processing record 121: {'DOS__c': '11/08/2024', 'Rev_Code__c': 301, 'Billed_Amount__c': 147.0, 'RHP_ID__c': nan, 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 147.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IuwQAE', 'Line_ID__c': 6, 'Exp_Code_2nd__c': nan}
# Error during insert: Malformed request https://relianthealthpartners2020--tctdev.sandbox.my.salesforce.com/services/data/v59.0/sobjects/Line_Items__c/. Response content: [{'message': 'Required fields are missing: [RHP_ID__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['RHP_ID__c']}]
# Processing record 122: {'DOS__c': '11/08/2024', 'Rev_Code__c': 301, 'Billed_Amount__c': 168.0, 'RHP_ID__c': nan, 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 168.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IyMQAU', 'Line_ID__c': 7, 'Exp_Code_2nd__c': nan}
# Error during insert: Malformed request https://relianthealthpartners2020--tctdev.sandbox.my.salesforce.com/services/data/v59.0/sobjects/Line_Items__c/. Response content: [{'message': 'Required fields are missing: [RHP_ID__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['RHP_ID__c']}]
# Processing record 123: {'DOS__c': '11/08/2024', 'Rev_Code__c': 305, 'Billed_Amount__c': 264.0, 'RHP_ID__c': nan, 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 264.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IyzQAE', 'Line_ID__c': 8, 'Exp_Code_2nd__c': nan}
# Error during insert: Malformed request https://relianthealthpartners2020--tctdev.sandbox.my.salesforce.com/services/data/v59.0/sobjects/Line_Items__c/. Response content: [{'message': 'Required fields are missing: [RHP_ID__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['RHP_ID__c']}]
# Processing record 124: {'DOS__c': '11/06/2024', 'Rev_Code__c': 510, 'Billed_Amount__c': 146.0, 'RHP_ID__c': 'a06VF00000AHWYoYAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 146.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1Ia4QAE', 'Line_ID__c': 1, 'Exp_Code_2nd__c': nan}
# Processing record 125: {'DOS__c': '10/15/2024', 'Rev_Code__c': 914, 'Billed_Amount__c': 1775.0, 'RHP_ID__c': 'a06VF00000AHZd7YAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 1775.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IOfQAM', 'Line_ID__c': 1, 'Exp_Code_2nd__c': 'C000'}
# Processing record 126: {'DOS__c': '10/15/2024', 'Rev_Code__c': 914, 'Billed_Amount__c': 525.0, 'RHP_ID__c': 'a06VF00000AHZd7YAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 525.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IOYQA2', 'Line_ID__c': 2, 'Exp_Code_2nd__c': 'C000'}
# Processing record 127: {'DOS__c': '10/24/2024', 'Rev_Code__c': 320, 'Billed_Amount__c': 643.0, 'RHP_ID__c': 'a06VF00000AHZIAYA5', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 144.05, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IFpQAM', 'Line_ID__c': 1, 'Exp_Code_2nd__c': nan}
# Processing record 128: {'DOS__c': '10/24/2024', 'Rev_Code__c': 352, 'Billed_Amount__c': 4549.0, 'RHP_ID__c': 'a06VF00000AHZIAYA5', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 174.28, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IG3QAM', 'Line_ID__c': 2, 'Exp_Code_2nd__c': nan}
# Processing record 129: {'DOS__c': '10/24/2024', 'Rev_Code__c': 450, 'Billed_Amount__c': 2520.0, 'RHP_ID__c': 'a06VF00000AHZIAYA5', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 527.48, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IaRQAU', 'Line_ID__c': 3, 'Exp_Code_2nd__c': nan}
# Processing record 130: {'DOS__c': '10/24/2024', 'Rev_Code__c': 637, 'Billed_Amount__c': 6.85, 'RHP_ID__c': 'a06VF00000AHZIAYA5', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 0.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 4, 'Exp_Code_2nd__c': nan}
# Processing record 131: {'DOS__c': '10/24/2024', 'Rev_Code__c': 637, 'Billed_Amount__c': 80.6, 'RHP_ID__c': 'a06VF00000AHZIAYA5', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 0.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 5, 'Exp_Code_2nd__c': nan}
# Processing record 132: {'DOS__c': '11/01/2024', 'Rev_Code__c': 250, 'Billed_Amount__c': 42.0, 'RHP_ID__c': 'a06VF00000AHVkoYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 42.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 1, 'Exp_Code_2nd__c': nan}
# Processing record 133: {'DOS__c': '11/01/2024', 'Rev_Code__c': 258, 'Billed_Amount__c': 76.0, 'RHP_ID__c': 'a06VF00000AHVkoYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 76.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 2, 'Exp_Code_2nd__c': nan}
# Processing record 134: {'DOS__c': '11/01/2024', 'Rev_Code__c': 272, 'Billed_Amount__c': 150.0, 'RHP_ID__c': 'a06VF00000AHVkoYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 5, 'MAR__c': 150.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 3, 'Exp_Code_2nd__c': nan}
# Processing record 135: {'DOS__c': '11/01/2024', 'Rev_Code__c': 300, 'Billed_Amount__c': 58.0, 'RHP_ID__c': 'a06VF00000AHVkoYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 2, 'MAR__c': 58.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1Ij6QAE', 'Line_ID__c': 4, 'Exp_Code_2nd__c': nan}
# Processing record 136: {'DOS__c': '11/01/2024', 'Rev_Code__c': 300, 'Billed_Amount__c': 139.0, 'RHP_ID__c': 'a06VF00000AHVkoYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 139.0, 'HCPCS_CPT_Code__c': 'a0b4W00000yewpfQAA', 'Line_ID__c': 5, 'Exp_Code_2nd__c': nan}
# Processing record 137: {'DOS__c': '11/01/2024', 'Rev_Code__c': 300, 'Billed_Amount__c': 93.0, 'RHP_ID__c': 'a06VF00000AHVkoYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 93.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1Iw3QAE', 'Line_ID__c': 6, 'Exp_Code_2nd__c': nan}
# Processing record 138: {'DOS__c': '11/01/2024', 'Rev_Code__c': 300, 'Billed_Amount__c': 117.0, 'RHP_ID__c': 'a06VF00000AHVkoYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 117.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1J4PQAU', 'Line_ID__c': 7, 'Exp_Code_2nd__c': nan}
# Processing record 139: {'DOS__c': '11/01/2024', 'Rev_Code__c': 300, 'Billed_Amount__c': 117.0, 'RHP_ID__c': 'a06VF00000AHVkoYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 117.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1J4tQAE', 'Line_ID__c': 8, 'Exp_Code_2nd__c': nan}
# Processing record 140: {'DOS__c': '11/01/2024', 'Rev_Code__c': 301, 'Billed_Amount__c': 263.0, 'RHP_ID__c': 'a06VF00000AHVkoYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 263.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IoNQAU', 'Line_ID__c': 9, 'Exp_Code_2nd__c': nan}
# Processing record 141: {'DOS__c': '11/01/2024', 'Rev_Code__c': 301, 'Billed_Amount__c': 145.0, 'RHP_ID__c': 'a06VF00000AHVkoYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 145.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1ItHQAU', 'Line_ID__c': 10, 'Exp_Code_2nd__c': nan}
# Processing record 142: {'DOS__c': '11/01/2024', 'Rev_Code__c': 301, 'Billed_Amount__c': 127.0, 'RHP_ID__c': 'a06VF00000AHVkoYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 127.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IusQAE', 'Line_ID__c': 11, 'Exp_Code_2nd__c': nan}
# Processing record 143: {'DOS__c': '11/01/2024', 'Rev_Code__c': 301, 'Billed_Amount__c': 87.0, 'RHP_ID__c': 'a06VF00000AHVkoYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 87.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IvzQAE', 'Line_ID__c': 12, 'Exp_Code_2nd__c': nan}
# Processing record 144: {'DOS__c': '11/01/2024', 'Rev_Code__c': 301, 'Billed_Amount__c': 185.0, 'RHP_ID__c': 'a06VF00000AHVkoYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 185.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IwCQAU', 'Line_ID__c': 13, 'Exp_Code_2nd__c': nan}
# Processing record 145: {'DOS__c': '11/01/2024', 'Rev_Code__c': 301, 'Billed_Amount__c': 250.0, 'RHP_ID__c': 'a06VF00000AHVkoYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 250.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IyTQAU', 'Line_ID__c': 14, 'Exp_Code_2nd__c': nan}
# Processing record 146: {'DOS__c': '11/01/2024', 'Rev_Code__c': 305, 'Billed_Amount__c': 105.0, 'RHP_ID__c': 'a06VF00000AHVkoYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 105.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IyzQAE', 'Line_ID__c': 15, 'Exp_Code_2nd__c': nan}
# Processing record 147: {'DOS__c': '11/01/2024', 'Rev_Code__c': 305, 'Billed_Amount__c': 87.0, 'RHP_ID__c': 'a06VF00000AHVkoYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 87.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IzxQAE', 'Line_ID__c': 16, 'Exp_Code_2nd__c': nan}
# Processing record 148: {'DOS__c': '11/01/2024', 'Rev_Code__c': 306, 'Billed_Amount__c': 174.0, 'RHP_ID__c': 'a06VF00000AHVkoYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 174.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1J2xQAE', 'Line_ID__c': 17, 'Exp_Code_2nd__c': nan}
# Processing record 149: {'DOS__c': '11/01/2024', 'Rev_Code__c': 306, 'Billed_Amount__c': 174.0, 'RHP_ID__c': 'a06VF00000AHVkoYAH', 'Mod__c': '91', 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 174.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1J2xQAE', 'Line_ID__c': 18, 'Exp_Code_2nd__c': nan}
# Processing record 150: {'DOS__c': '11/01/2024', 'Rev_Code__c': 307, 'Billed_Amount__c': 93.0, 'RHP_ID__c': 'a06VF00000AHVkoYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 93.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IqSQAU', 'Line_ID__c': 19, 'Exp_Code_2nd__c': nan}
# Processing record 151: {'DOS__c': '11/01/2024', 'Rev_Code__c': 352, 'Billed_Amount__c': 4396.0, 'RHP_ID__c': 'a06VF00000AHVkoYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 4396.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IGNQA2', 'Line_ID__c': 20, 'Exp_Code_2nd__c': nan}
# Processing record 152: {'DOS__c': '11/01/2024', 'Rev_Code__c': 450, 'Billed_Amount__c': 159.0, 'RHP_ID__c': 'a06VF00000AHVkoYAH', 'Mod__c': '59', 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 159.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1Ij0QAE', 'Line_ID__c': 21, 'Exp_Code_2nd__c': nan}
# Processing record 153: {'DOS__c': '11/01/2024', 'Rev_Code__c': 450, 'Billed_Amount__c': 436.0, 'RHP_ID__c': 'a06VF00000AHVkoYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 436.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IXyQAM', 'Line_ID__c': 22, 'Exp_Code_2nd__c': nan}
# Processing record 154: {'DOS__c': '11/01/2024', 'Rev_Code__c': 450, 'Billed_Amount__c': 264.0, 'RHP_ID__c': 'a06VF00000AHVkoYAH', 'Mod__c': '59', 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 264.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IY9QAM', 'Line_ID__c': 23, 'Exp_Code_2nd__c': nan}
# Processing record 155: {'DOS__c': '11/01/2024', 'Rev_Code__c': 450, 'Billed_Amount__c': 1206.0, 'RHP_ID__c': 'a06VF00000AHVkoYAH', 'Mod__c': '25', 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 1206.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IaTQAU', 'Line_ID__c': 24, 'Exp_Code_2nd__c': nan}
# Processing record 156: {'DOS__c': '11/01/2024', 'Rev_Code__c': 730, 'Billed_Amount__c': 357.0, 'RHP_ID__c': 'a06VF00000AHVkoYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 357.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IRyQAM', 'Line_ID__c': 25, 'Exp_Code_2nd__c': nan}
# Processing record 157: {'DOS__c': '10/31/2024', 'Rev_Code__c': 259, 'Billed_Amount__c': 70.58, 'RHP_ID__c': 'a06VF00000AHZejYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 70.58, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 1, 'Exp_Code_2nd__c': nan}
# Processing record 158: {'DOS__c': '10/31/2024', 'Rev_Code__c': 350, 'Billed_Amount__c': 2824.85, 'RHP_ID__c': 'a06VF00000AHZejYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 2824.85, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IDXQA2', 'Line_ID__c': 2, 'Exp_Code_2nd__c': nan}
# Processing record 159: {'DOS__c': '10/31/2024', 'Rev_Code__c': 350, 'Billed_Amount__c': 6108.48, 'RHP_ID__c': 'a06VF00000AHZejYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 6108.48, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IDdQAM', 'Line_ID__c': 3, 'Exp_Code_2nd__c': nan}
# Processing record 160: {'DOS__c': '10/31/2024', 'Rev_Code__c': 350, 'Billed_Amount__c': 5750.0, 'RHP_ID__c': 'a06VF00000AHZejYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 5750.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IEaQAM', 'Line_ID__c': 4, 'Exp_Code_2nd__c': nan}
# Processing record 161: {'DOS__c': '10/31/2024', 'Rev_Code__c': 450, 'Billed_Amount__c': 2619.5, 'RHP_ID__c': 'a06VF00000AHZejYAH', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 2619.5, 'HCPCS_CPT_Code__c': 'a0b4W00000y1GmpQAE', 'Line_ID__c': 5, 'Exp_Code_2nd__c': nan}
# Processing record 162: {'DOS__c': '10/31/2024', 'Rev_Code__c': 450, 'Billed_Amount__c': 7874.25, 'RHP_ID__c': 'a06VF00000AHZejYAH', 'Mod__c': '25', 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 7874.25, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IaTQAU', 'Line_ID__c': 6, 'Exp_Code_2nd__c': nan}
# Processing record 163: {'DOS__c': '07/19/2024', 'Rev_Code__c': 402, 'Billed_Amount__c': 2249.0, 'RHP_ID__c': 'a06VF00000AHSINYA5', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 2249.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IJ0QAM', 'Line_ID__c': 1, 'Exp_Code_2nd__c': nan}
# Processing record 164: {'DOS__c': '07/19/2024', 'Rev_Code__c': 921, 'Billed_Amount__c': 2236.0, 'RHP_ID__c': 'a06VF00000AHSINYA5', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 2236.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IUZQA2', 'Line_ID__c': 2, 'Exp_Code_2nd__c': nan}
# ...
# Processing record 390: {'DOS__c': '10/22/2024', 'Rev_Code__c': 490, 'Billed_Amount__c': 5590.87, 'RHP_ID__c': 'a06VF00000AHXLCYA5', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 900.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1I5fQAE', 'Line_ID__c': 3, 'Exp_Code_2nd__c': nan}
# Processing record 391: {'DOS__c': '10/22/2024', 'Rev_Code__c': 490, 'Billed_Amount__c': 5590.87, 'RHP_ID__c': 'a06VF00000AHXLCYA5', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 900.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1I5fQAE', 'Line_ID__c': 4, 'Exp_Code_2nd__c': nan}
# Processing record 392: {'DOS__c': '10/25/2024', 'Rev_Code__c': 350, 'Billed_Amount__c': 10488.0, 'RHP_ID__c': 'a06VF00000AHXLDYA5', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 611.33, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IGPQA2', 'Line_ID__c': 1, 'Exp_Code_2nd__c': nan}
# Processing record 393: {'DOS__c': '10/25/2024', 'Rev_Code__c': 350, 'Billed_Amount__c': 1824.0, 'RHP_ID__c': 'a06VF00000AHXLDYA5', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 0.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IIJQA2', 'Line_ID__c': 2, 'Exp_Code_2nd__c': nan}
# Processing record 394: {'DOS__c': '10/25/2024', 'Rev_Code__c': 636, 'Billed_Amount__c': 560.0, 'RHP_ID__c': 'a06VF00000AHXLDYA5', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 140, 'MAR__c': 0.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1JjHQAU', 'Line_ID__c': 3, 'Exp_Code_2nd__c': nan}
# Processing record 395: {'DOS__c': '10/28/2024', 'Rev_Code__c': 731, 'Billed_Amount__c': 286.0, 'RHP_ID__c': 'a06VF00000AHYZ1YAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 286.0, 'HCPCS_CPT_Code__c': 'a0b8a00000fHBLPAA4', 'Line_ID__c': 1, 'Exp_Code_2nd__c': nan}
# Processing record 396: {'DOS__c': '11/06/2024', 'Rev_Code__c': 126, 'Billed_Amount__c': 4900.0, 'RHP_ID__c': 'a06VF00000AHXbNYAX', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 4900.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 1, 'Exp_Code_2nd__c': nan}
# Processing record 397: {'DOS__c': '08/07/2024', 'Rev_Code__c': 490, 'Billed_Amount__c': 17723.0, 'RHP_ID__c': 'a06VF00000AHaFqYAL', 'Mod__c': 'LT', 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 3026.24, 'HCPCS_CPT_Code__c': 'a0b4W00000y1HG9QAM', 'Line_ID__c': 1, 'Exp_Code_2nd__c': nan}
# Processing record 398: {'DOS__c': '08/07/2024', 'Rev_Code__c': 490, 'Billed_Amount__c': 15331.0, 'RHP_ID__c': 'a06VF00000AHaFqYAL', 'Mod__c': 'LT', 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 0.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1HGCQA2', 'Line_ID__c': 2, 'Exp_Code_2nd__c': nan}
# Processing record 399: {'DOS__c': '11/07/2024', 'Rev_Code__c': 309, 'Billed_Amount__c': 264.0, 'RHP_ID__c': 'a06VF00000AHZWhYAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 264.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1J6SQAU', 'Line_ID__c': 1, 'Exp_Code_2nd__c': nan}
# Processing record 400: {'DOS__c': '11/04/2024', 'Rev_Code__c': 300, 'Billed_Amount__c': 22.0, 'RHP_ID__c': 'a06VF00000AHUGzYAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 22.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1Ij6QAE', 'Line_ID__c': 1, 'Exp_Code_2nd__c': nan}
# Processing record 401: {'DOS__c': '11/04/2024', 'Rev_Code__c': 301, 'Billed_Amount__c': 93.0, 'RHP_ID__c': 'a06VF00000AHUGzYAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 93.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IoNQAU', 'Line_ID__c': 2, 'Exp_Code_2nd__c': nan}
# Processing record 402: {'DOS__c': '11/04/2024', 'Rev_Code__c': 301, 'Billed_Amount__c': 119.0, 'RHP_ID__c': 'a06VF00000AHUGzYAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 119.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IoPQAU', 'Line_ID__c': 3, 'Exp_Code_2nd__c': nan}
# Processing record 403: {'DOS__c': '11/04/2024', 'Rev_Code__c': 301, 'Billed_Amount__c': 278.0, 'RHP_ID__c': 'a06VF00000AHUGzYAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 278.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1ItaQAE', 'Line_ID__c': 4, 'Exp_Code_2nd__c': nan}
# Processing record 404: {'DOS__c': '11/04/2024', 'Rev_Code__c': 305, 'Billed_Amount__c': 69.0, 'RHP_ID__c': 'a06VF00000AHUGzYAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 69.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IyzQAE', 'Line_ID__c': 5, 'Exp_Code_2nd__c': nan}
# Processing record 405: {'DOS__c': '11/09/2024', 'Rev_Code__c': 450, 'Billed_Amount__c': 2264.22, 'RHP_ID__c': 'a06VF00000AHaMHYA1', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 2264.22, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IaTQAU', 'Line_ID__c': 1, 'Exp_Code_2nd__c': nan}
# Processing record 406: {'DOS__c': '11/09/2024', 'Rev_Code__c': 637, 'Billed_Amount__c': 5.82, 'RHP_ID__c': 'a06VF00000AHaMHYA1', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 5.82, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 2, 'Exp_Code_2nd__c': nan}
# Processing record 407: {'DOS__c': '11/09/2024', 'Rev_Code__c': 637, 'Billed_Amount__c': 4.55, 'RHP_ID__c': 'a06VF00000AHaMHYA1', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 4.55, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 3, 'Exp_Code_2nd__c': nan}
# Processing record 408: {'DOS__c': '10/28/2024', 'Rev_Code__c': 111, 'Billed_Amount__c': 3132.0, 'RHP_ID__c': 'a06VF00000AHXZiYAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 3132.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 1, 'Exp_Code_2nd__c': nan}
# Processing record 409: {'DOS__c': '10/28/2024', 'Rev_Code__c': 250, 'Billed_Amount__c': 1199.61, 'RHP_ID__c': 'a06VF00000AHXZiYAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 20, 'MAR__c': 1199.61, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 2, 'Exp_Code_2nd__c': nan}
# Processing record 410: {'DOS__c': '10/28/2024', 'Rev_Code__c': 300, 'Billed_Amount__c': 2444.0, 'RHP_ID__c': 'a06VF00000AHXZiYAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 3, 'MAR__c': 2444.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 3, 'Exp_Code_2nd__c': nan}
# Processing record 411: {'DOS__c': '10/28/2024', 'Rev_Code__c': 320, 'Billed_Amount__c': 913.0, 'RHP_ID__c': 'a06VF00000AHXZiYAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 913.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 4, 'Exp_Code_2nd__c': nan}
# Processing record 412: {'DOS__c': '10/28/2024', 'Rev_Code__c': 360, 'Billed_Amount__c': 37700.0, 'RHP_ID__c': 'a06VF00000AHXZiYAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 5, 'MAR__c': 37700.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 5, 'Exp_Code_2nd__c': nan}
# Processing record 413: {'DOS__c': '10/28/2024', 'Rev_Code__c': 370, 'Billed_Amount__c': 7254.0, 'RHP_ID__c': 'a06VF00000AHXZiYAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 5, 'MAR__c': 7254.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 6, 'Exp_Code_2nd__c': nan}
# Processing record 414: {'DOS__c': '10/28/2024', 'Rev_Code__c': 636, 'Billed_Amount__c': 280.0, 'RHP_ID__c': 'a06VF00000AHXZiYAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 10, 'MAR__c': 280.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1JVsQAM', 'Line_ID__c': 7, 'Exp_Code_2nd__c': nan}
# Processing record 415: {'DOS__c': '10/28/2024', 'Rev_Code__c': 636, 'Billed_Amount__c': 432.0, 'RHP_ID__c': 'a06VF00000AHXZiYAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 8, 'MAR__c': 432.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 8, 'Exp_Code_2nd__c': nan}
# Processing record 416: {'DOS__c': '10/28/2024', 'Rev_Code__c': 636, 'Billed_Amount__c': 24.0, 'RHP_ID__c': 'a06VF00000AHXZiYAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 8, 'MAR__c': 24.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1JX9QAM', 'Line_ID__c': 9, 'Exp_Code_2nd__c': nan}
# Processing record 417: {'DOS__c': '10/28/2024', 'Rev_Code__c': 636, 'Billed_Amount__c': 20.0, 'RHP_ID__c': 'a06VF00000AHXZiYAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 2, 'MAR__c': 20.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1JYRQA2', 'Line_ID__c': 10, 'Exp_Code_2nd__c': nan}
# Processing record 418: {'DOS__c': '10/28/2024', 'Rev_Code__c': 636, 'Billed_Amount__c': 570.0, 'RHP_ID__c': 'a06VF00000AHXZiYAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 3, 'MAR__c': 570.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1JYTQA2', 'Line_ID__c': 11, 'Exp_Code_2nd__c': nan}
# Processing record 419: {'DOS__c': '10/28/2024', 'Rev_Code__c': 636, 'Billed_Amount__c': 44.0, 'RHP_ID__c': 'a06VF00000AHXZiYAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 4, 'MAR__c': 44.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1JYkQAM', 'Line_ID__c': 12, 'Exp_Code_2nd__c': nan}
# Processing record 420: {'DOS__c': '10/28/2024', 'Rev_Code__c': 636, 'Billed_Amount__c': 80.0, 'RHP_ID__c': 'a06VF00000AHXZiYAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 20, 'MAR__c': 80.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1JZ9QAM', 'Line_ID__c': 13, 'Exp_Code_2nd__c': nan}
# Processing record 421: {'DOS__c': '10/28/2024', 'Rev_Code__c': 636, 'Billed_Amount__c': 9.0, 'RHP_ID__c': 'a06VF00000AHXZiYAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 9.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1JZdQAM', 'Line_ID__c': 14, 'Exp_Code_2nd__c': nan}
# Processing record 422: {'DOS__c': '10/28/2024', 'Rev_Code__c': 636, 'Billed_Amount__c': 422.0, 'RHP_ID__c': 'a06VF00000AHXZiYAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 422.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1JahQAE', 'Line_ID__c': 15, 'Exp_Code_2nd__c': nan}
# Processing record 423: {'DOS__c': '10/28/2024', 'Rev_Code__c': 710, 'Billed_Amount__c': 7330.0, 'RHP_ID__c': 'a06VF00000AHXZiYAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 5, 'MAR__c': 7330.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 16, 'Exp_Code_2nd__c': nan}
# Processing record 424: {'DOS__c': '10/28/2024', 'Rev_Code__c': 730, 'Billed_Amount__c': 1137.0, 'RHP_ID__c': 'a06VF00000AHXZiYAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 1137.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 17, 'Exp_Code_2nd__c': nan}
# Processing record 425: {'DOS__c': '10/28/2024', 'Rev_Code__c': 740, 'Billed_Amount__c': 1999.0, 'RHP_ID__c': 'a06VF00000AHXZiYAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 1999.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 18, 'Exp_Code_2nd__c': nan}
# Processing record 426: {'DOS__c': '10/28/2024', 'Rev_Code__c': 922, 'Billed_Amount__c': 3203.0, 'RHP_ID__c': 'a06VF00000AHXZiYAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 3203.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 19, 'Exp_Code_2nd__c': nan}
# Processing record 427: {'DOS__c': '11/10/2024', 'Rev_Code__c': 126, 'Billed_Amount__c': 7705.0, 'RHP_ID__c': 'a06VF00000AHUlWYAX', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 7705.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 1, 'Exp_Code_2nd__c': 'C000'}
# Processing record 428: {'DOS__c': '10/29/2024', 'Rev_Code__c': 1002, 'Billed_Amount__c': 4700.0, 'RHP_ID__c': 'a06VF00000AHQWeYAP', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 0.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1JUwQAM', 'Line_ID__c': 1, 'Exp_Code_2nd__c': 'C286'}
# Processing record 429: {'DOS__c': '11/04/2024', 'Rev_Code__c': 510, 'Billed_Amount__c': 303.0, 'RHP_ID__c': 'a06VF00000AHOmYYAX', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 303.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1Ia5QAE', 'Line_ID__c': 1, 'Exp_Code_2nd__c': nan}
# Processing record 430: {'DOS__c': '09/23/2024', 'Rev_Code__c': 1001, 'Billed_Amount__c': 3800.0, 'RHP_ID__c': 'a06VF00000AHZtGYAX', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 3800.0, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 1, 'Exp_Code_2nd__c': 'C000'}
# Processing record 431: {'DOS__c': '11/04/2024', 'Rev_Code__c': 420, 'Billed_Amount__c': 340.4, 'RHP_ID__c': nan, 'Mod__c': 'GP', 'Mod_2nd__c': nan, 'Units__c': 2, 'MAR__c': 340.4, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IZ5QAM', 'Line_ID__c': 1, 'Exp_Code_2nd__c': nan}
# Error during insert: Malformed request https://relianthealthpartners2020--tctdev.sandbox.my.salesforce.com/services/data/v59.0/sobjects/Line_Items__c/. Response content: [{'message': 'Required fields are missing: [RHP_ID__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['RHP_ID__c']}]
# Processing record 432: {'DOS__c': '09/06/2024', 'Rev_Code__c': 250, 'Billed_Amount__c': 0.76, 'RHP_ID__c': 'a06VF00000AHNiRYAX', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 2, 'MAR__c': 0.76, 'HCPCS_CPT_Code__c': nan, 'Line_ID__c': 1, 'Exp_Code_2nd__c': nan}
# Processing record 433: {'DOS__c': '09/06/2024', 'Rev_Code__c': 300, 'Billed_Amount__c': 1531.0, 'RHP_ID__c': 'a06VF00000AHNiRYAX', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 1531.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IoNQAU', 'Line_ID__c': 2, 'Exp_Code_2nd__c': nan}
# Processing record 434: {'DOS__c': '09/06/2024', 'Rev_Code__c': 300, 'Billed_Amount__c': 1734.0, 'RHP_ID__c': 'a06VF00000AHNiRYAX', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 2, 'MAR__c': 1734.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IyTQAU', 'Line_ID__c': 3, 'Exp_Code_2nd__c': nan}
# Processing record 435: {'DOS__c': '09/06/2024', 'Rev_Code__c': 300, 'Billed_Amount__c': 1134.0, 'RHP_ID__c': 'a06VF00000AHNiRYAX', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 1134.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IylQAE', 'Line_ID__c': 4, 'Exp_Code_2nd__c': nan}
# Processing record 436: {'DOS__c': '09/06/2024', 'Rev_Code__c': 300, 'Billed_Amount__c': 605.0, 'RHP_ID__c': 'a06VF00000AHNiRYAX', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 605.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IymQAE', 'Line_ID__c': 5, 'Exp_Code_2nd__c': nan}
# Processing record 437: {'DOS__c': '09/06/2024', 'Rev_Code__c': 300, 'Billed_Amount__c': 312.0, 'RHP_ID__c': 'a06VF00000AHNiRYAX', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 312.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IyzQAE', 'Line_ID__c': 6, 'Exp_Code_2nd__c': nan}
# Processing record 438: {'DOS__c': '09/06/2024', 'Rev_Code__c': 320, 'Billed_Amount__c': 767.0, 'RHP_ID__c': 'a06VF00000AHNiRYAX', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 767.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IE2QAM', 'Line_ID__c': 7, 'Exp_Code_2nd__c': nan}
# Processing record 439: {'DOS__c': '09/06/2024', 'Rev_Code__c': 450, 'Billed_Amount__c': 976.0, 'RHP_ID__c': 'a06VF00000AHNiRYAX', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 976.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IY0QAM', 'Line_ID__c': 8, 'Exp_Code_2nd__c': nan}
# Processing record 440: {'DOS__c': '09/06/2024', 'Rev_Code__c': 450, 'Billed_Amount__c': 243.0, 'RHP_ID__c': 'a06VF00000AHNiRYAX', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 243.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IY1QAM', 'Line_ID__c': 9, 'Exp_Code_2nd__c': nan}
# Processing record 441: {'DOS__c': '09/06/2024', 'Rev_Code__c': 450, 'Billed_Amount__c': 459.0, 'RHP_ID__c': 'a06VF00000AHNiRYAX', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 459.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IYAQA2', 'Line_ID__c': 10, 'Exp_Code_2nd__c': nan}
# Processing record 442: {'DOS__c': '09/06/2024', 'Rev_Code__c': 450, 'Billed_Amount__c': 5193.0, 'RHP_ID__c': 'a06VF00000AHNiRYAX', 'Mod__c': '25', 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 5193.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IaTQAU', 'Line_ID__c': 11, 'Exp_Code_2nd__c': nan}
# Processing record 443: {'DOS__c': '09/06/2024', 'Rev_Code__c': 636, 'Billed_Amount__c': 28.0, 'RHP_ID__c': 'a06VF00000AHNiRYAX', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 2, 'MAR__c': 28.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1JY1QAM', 'Line_ID__c': 12, 'Exp_Code_2nd__c': nan}
# Processing record 444: {'DOS__c': '09/06/2024', 'Rev_Code__c': 636, 'Billed_Amount__c': 20.0, 'RHP_ID__c': 'a06VF00000AHNiRYAX', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 4, 'MAR__c': 20.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1Ja9QAE', 'Line_ID__c': 13, 'Exp_Code_2nd__c': nan}
# Processing record 445: {'DOS__c': '09/06/2024', 'Rev_Code__c': 730, 'Billed_Amount__c': 1053.0, 'RHP_ID__c': 'a06VF00000AHNiRYAX', 'Mod__c': nan, 'Mod_2nd__c': nan, 'Units__c': 1, 'MAR__c': 1053.0, 'HCPCS_CPT_Code__c': 'a0b4W00000y1IRyQAM', 'Line_ID__c': 14, 'Exp_Code_2nd__c': nan}
# Total records inserted: 425
# Total errors logged: 21

# %%
source_cases = Source_data.drop_duplicates(subset=['Claim ID'])[['Claim ID']]
ids = list(source_cases.merge(updated_data_pull(['Claims__c'], sf), left_on='Claim ID', right_on='Claim_ID__c').loc[:, ['Claim ID', 'Claim_ID__c', 'Id']]['Id'])
len(ids)
# Out:
# pulled Claims__c
# 103

# %%
################# delete records:
keys = {'Claims__c':'Claim_ID__c'}
delete_record(ids, keys, sf)
# Out:
# Object: Claims__c, Records to process: 103
# All records deleted successfully.

# %%
groups_clients_sf = my_sf_objects['Groups_Clients__c']
groups_clients_sf.shape
# Out:
# (1703, 59)

# %%
map_claims_table[map_claims_table['Group_Client__c'].isna()].drop_duplicates()
# Out:
#               Claim_ID__c     Provider_TIN__c Group_Client__c  \
# 116  1E6E757A964D548tksft  a0F4W00000W1KH5UAN             NaN
# 202  B17551A5CD4B233tksft  a0F4W00000W1LEEUA3             NaN
# 214  24BF09BD7288E97tksft  a0FVF0000020PQH2A2             NaN
# 272  0D8755A2AD0EBC0tksft  a0FVF0000020Onc2AE             NaN
# 374  0B46B602A7B3B67tksft  a0FVF0000020PbZ2AU             NaN
# 431  802EF0AD00A30E7tksft  a0FVF0000020Pen2AE             NaN
#
#         Claim_Number__c     Jurisdiction__c Diag_Code__c Diag_Code_2nd__c  \
# 116     18A91B0008179A1  a024W00000HYAjJQAX          C20            C7951
# 202     18A91B0008179A8  a024W00000HYAjRQAX        Z5181           Z79899
# 214     06A11B00081784F  a024W00000HYAjkQAH       M25532          X500XXA
# 272      P24319I2000001  a024W00000HYAjRQAX       Z01818             N871
# 374  21040838Accredited  a024W00000HYAj9QAH        M5416              NaN
# 431     18A91B0008179EE  a024W00000HYAjoQAH        M2352              NaN
#
#     Diag_Code_3rd__c Diag_Code_4th__c                         Provider__c  \
# 116            R6889              NaN            METHODIST HOSPITALSINC.
# 202              NaN              NaN            FREEMAN NEOSHO HOSPITAL
# 214              NaN              NaN  PFLUGERVILLE EMERGENCY CENTER LLC
# 272              NaN              NaN         CURATORS OF THE UNIVERSITY
# 374              NaN              NaN        SURGCENTER NORTHERN PHOENIX
# 431              NaN              NaN         SEATTLE CHILDRENS HOSPITAL
#
#             Patient__c Patient_ID__c Date_of_Birth__c  Provider_Zip__c DRG__c  \
# 116   ROODZANT JAMES       880263595       12/22/1971        464107035    NaN
# 202   WILSON ROBERT  L     880440969       03/12/1960        648501705    NaN
# 214    INABINETT COLE      750076498       05/27/2011        786605965    NaN
# 272    ARNOLD ASHLEY       489984314       05/19/1988        652120001    NaN
# 374        PEN KEVIN       XXXXX1120       11/22/1981        850859998    NaN
# 431  JOHNSTON HARPER A     880402012       09/16/2009        980043829    NaN
#
#     QPA__c        NPI__c  POS__c Provider_Specialty__c Service_Type__c
# 116      N  1.518035e+09      13                   NaN             NaN
# 202      N  1.154990e+09      85                   NaN             NaN
# 214      Y  1.154762e+09      13                   NaN             NaN
# 272      Y           NaN      22                   NaN             NaN
# 374      N           NaN      83    a008a000015yXNEAA2  SURGERY CENTER
# 431      N  1.316174e+09      13                   NaN             NaN

# %%
for i in sorted(list(groups_clients_sf['Group_Number__c'])):
    if '' in i:
        print(i)
# Out:
# 330803325RELAccidentFund
